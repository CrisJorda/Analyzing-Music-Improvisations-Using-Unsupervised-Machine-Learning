# %%
import os
import time

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torchvision.utils
import torch.nn.functional as F
import torchvision.transforms as transforms

from typing import Tuple
from torchvision import datasets
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, MDS
# !pip install umap-learn
import umap

from PIL import Image

import seaborn as sns

import pandas as pd
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 817.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=e6c50a171e9fa80c2d4bc3d13246185ee10eb93b87742b2283fcb7679ea0cbd2
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5

# %%
seed = 123
np.random.seed(seed)
_ = torch.manual_seed(seed)
_ = torch.cuda.manual_seed(seed)

# %%
# we select to work on GPU if it is available in the machine, otherwise will run on CPU
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Defining the Hyper-parameters**

# %%
hparams = {
    'batch_size':128,
    'num_epochs':300,
    'channels':64,
    'latent_dims':70,
    'variational_beta':1,
    'learning_rate':1e-4,
    'weight_decay':1e-5,
    'dropout_prob':0.1
}

# %% [markdown]
# **Defining the Pytorch Dataset and the DataLoader**

# %%
# Define a custom transformation function
def custom_transform(piano_roll_data):
    # Convert the binary piano roll data to a NumPy array
    piano_roll_array = np.array(piano_roll_data, dtype=np.float32)

    # Convert the NumPy array to a PIL Image
    piano_roll_image = Image.fromarray(piano_roll_array)

    # Apply any additional transformations if needed
    transform = transforms.Compose([
        transforms.Resize((25, 72)),
        transforms.ToTensor(),
    ])
    piano_roll_image = transform(piano_roll_image)

    return piano_roll_image

# %%
class PianoRollImageDataset(Dataset):
    def __init__(self, data_folder, file_list, transform=None):
        self.data_folder = data_folder
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        file_path = os.path.join(self.data_folder, file_name)

        piano_roll_data = []
        # Read the piano roll data from the text file
        with open(file_path, "r") as file:
            for i, line in enumerate(file):
                piano_roll_data.append([int(val) for val in line.split()])

        # Check the dimensions
        vertical_dimension = len(piano_roll_data)
        horizontal_dimension = len(piano_roll_data[0])

        # Convert to a PyTorch tensor using the custom transformation
        piano_roll_image = custom_transform(piano_roll_data)

        return piano_roll_image, file_name

# %%
# Define the data folder
data_folder = '/content/drive/MyDrive/TFM/68_4_bar_dataset'

# Split the dataset into training, validation, and test sets
file_list = os.listdir(data_folder) # 1913 files
train_files, val_files = train_test_split(file_list, test_size=0.3, random_state=42)
val_files, test_files = train_test_split(val_files, test_size=0.333, random_state=42)

# Dataset initialization
train_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=train_files)
val_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=val_files)
test_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=test_files)

# Dataloaders initialization
train_dataloader = torch.utils.data.DataLoader(
    dataset=train_dataset,
    batch_size=hparams['batch_size'],
    shuffle=True,
    drop_last=True,
)

val_dataloader = torch.utils.data.DataLoader(
    dataset=val_dataset,
    batch_size=hparams['batch_size'],
    shuffle=False,
    drop_last=True,
)

test_dataloader = torch.utils.data.DataLoader(
    dataset=test_dataset,
    batch_size=192,
    shuffle=False,
    drop_last=True,
)

# %%
print(len(train_dataset)) # 70%
print(len(val_dataset)) # 20%
print(len(test_dataset)) # 10%
# Out:
# 1339
# 382
# 192

# %%
# Define the participant ID you want to extract
participant_id = "A01"

# Get all files related to the participant_id from the data_folder
participant_files = [file_name for file_name in file_list if participant_id in file_name]

# Dataset initialization for the specific participant
participant_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=participant_files)

# Dataloader initialization for the specific participant
participant_dataloader = DataLoader(
    dataset=participant_dataset,
    batch_size=30,
    shuffle=False,
    drop_last=True,
)

# %%
whole_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=file_list)

# Dataloader initialization for the specific participant
whole_dataloader = DataLoader(
    dataset=whole_dataset,
    batch_size=len(whole_dataset),
    shuffle=False,
    drop_last=True,
)

# %% [markdown]
# **VAE Definition**

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            channels: int,
            latent_dims: int,
            ) -> None:

        super(Encoder, self).__init__()

        self.c = channels
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=self.c, kernel_size=(25,6), stride=1, padding=3)
        self.dropout1 = nn.Dropout2d(p=hparams['dropout_prob'])
        self.conv2 = nn.Conv2d(in_channels=self.c, out_channels=self.c*2, kernel_size=7, stride=2, padding=3)
        self.dropout2 = nn.Dropout2d(p=hparams['dropout_prob'])
        self.fc_mu = nn.Linear(in_features=self.c*2*4*37, out_features=hparams['latent_dims'])
        self.fc_logvar = nn.Linear(in_features=self.c*2*4*37, out_features=hparams['latent_dims'])

    def forward(self, x: torch.Tensor)-> Tuple[torch.Tensor, torch.Tensor]:
        #print(x.shape) # [128, 1, 25, 72]
        out = F.relu(self.conv1(x))
        #print(out.shape) # [128, 64, 7, 73]
        out = self.dropout1(out)
        out = F.relu(self.conv2(out))
        #print(out.shape) # [128, 128, 4, 37]
        out = self.dropout2(out)
        out = out.view(out.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        #print(out.shape) # [128, 18944]

        x_mu = self.fc_mu(out)
        #print(x_mu.shape) # [128, 512]
        x_logvar = self.fc_logvar(out)
        #print(x_logvar.shape) # [128, 512]

        return x_mu, x_logvar

# %%
class Decoder(nn.Module):
    def __init__(
            self,
            channels: int,
            latent_dims: int
            ) -> None:

        super(Decoder, self).__init__()
        self.c = channels
        self.fc = nn.Linear(in_features=hparams['latent_dims'], out_features=self.c*2*4*37)
        self.conv2 = nn.ConvTranspose2d(in_channels=self.c*2, out_channels=self.c, kernel_size=7, stride=2, padding=3)
        self.dropout1 = nn.Dropout2d(p=hparams['dropout_prob'])
        self.conv1 = nn.ConvTranspose2d(in_channels=self.c, out_channels=1, kernel_size=(25,6), stride=1, padding=3)

    def forward(self, z: torch.Tensor) -> torch.Tensor:
        #print(z.shape) # [128, 512]

        out = self.fc(z)
        #print(out.shape) # [128, 18944]
        out = out.view(out.size(0), self.c*2, 4, 37) # unflatten batch
        #print(out.shape) # [128, 128, 4, 37]
        out = F.relu(self.conv2(out))
        #print(out.shape) # [128, 64, 7, 73]
        out = self.dropout1(out)
        out = torch.sigmoid(self.conv1(out, output_size=(out.size(0), 1, 25, 72))) # without output_size, out would be [128, 1, 24, 72]
        #print(out.shape) # [128, 1, 25, 72]

        return out

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(
            self,
            z_dims: int,
            n_ch: int,
            ) -> None:

        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder(channels=n_ch,latent_dims=z_dims)
        self.decoder = Decoder(channels=n_ch, latent_dims=z_dims)

    def reparametrize(
            self,
            mu:torch.Tensor,
            logvar:torch.Tensor,
            ) -> torch.Tensor:
        # Given mean and logvar returns z
        # reparameterization trick: instead of sampling from Q(z|X), sample epsilon = N(0,I)
        # mu, logvar: mean and log of variance of Q(z|X)

        # The factor 1/2 in the exponent ensures that the distribution has unit variance
        std = torch.exp(0.5 * logvar)
        # Random sample
        eps = torch.randn_like(std)
        return mu + std * eps

    def forward(self, x: torch.Tensor) -> Tuple[
            torch.Tensor, torch.Tensor, torch.Tensor]:
        latent_mu, latent_logvar = self.encoder(x)
        z = self.reparametrize(latent_mu, latent_logvar)
        x_recon = self.decoder(z)

        return x_recon, latent_mu, latent_logvar

# %% [markdown]
# **Define Loss Function**

# %%
def vae_loss(
        recon_x: torch.Tensor,
        x: torch.Tensor,
        mu: torch.Tensor,
        logvar: torch.Tensor,
        variational_beta: int=1,
        ) -> float:
    # recon_x is the probability of a multivariate Bernoulli distribution p.
    # -log(p(x)) is then the pixel-wise binary cross-entropy.

    input_size = x.size(2) * x.size(3)

    recon_loss = F.binary_cross_entropy(recon_x.view(-1, input_size), x.view(-1, input_size), reduction='sum')
    kldivergence = variational_beta * (-0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()))
    elbo_loss = (recon_loss +  kldivergence)/x.shape[0]

    return elbo_loss, recon_loss, kldivergence

# %% [markdown]
# **Training**

# %%
def train_batch(
        image_batch: torch.Tensor,
        vae: torch.nn.Module,
        vae_loss: torch.nn.Module,
        optimizer: torch.optim,
        ) -> float:

    image_batch = image_batch.to(device) # [128, 1, 25, 72]

    image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
    elbo_loss, recon_loss, kldivergence = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

    # backpropagation
    optimizer.zero_grad()
    elbo_loss.backward()

    # one step of the optmizer (using the gradients from backpropagation)
    optimizer.step()

    return elbo_loss.item(), recon_loss.item(), kldivergence.item()

# %%
# Load checkpoint
checkpoint=torch.load('/content/drive/MyDrive/TFM/my_vae_2.pth', map_location=torch.device('cpu'))

vae = VariationalAutoencoder(z_dims = hparams['latent_dims'], n_ch = hparams['channels'])
vae.load_state_dict(checkpoint)
print('model loaded')

vae.to(device)
# Out:
# model loaded
# VariationalAutoencoder(
#   (encoder): Encoder(
#     (conv1): Conv2d(1, 64, kernel_size=(25, 6), stride=(1, 1), padding=(3, 3))
#     (dropout1): Dropout2d(p=0.1, inplace=False)
#     (conv2): Conv2d(64, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (dropout2): Dropout2d(p=0.1, inplace=False)
#     (fc_mu): Linear(in_features=18944, out_features=70, bias=True)
#     (fc_logvar): Linear(in_features=18944, out_features=70, bias=True)
#   )
#   (decoder): Decoder(
#     (fc): Linear(in_features=70, out_features=18944, bias=True)
#     (conv2): ConvTranspose2d(128, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (dropout1): Dropout2d(p=0.1, inplace=False)
#     (conv1): ConvTranspose2d(64, 1, kernel_size=(25, 6), stride=(1, 1), padding=(3, 3))
#   )
# )

# %%
# Freeze convolutional layers in the encoder
for name, param in vae.encoder.named_parameters():
    if 'conv' in name:  # Assuming your convolutional layers have 'conv' in their names
        param.requires_grad = False

# Freeze convolutional layers in the decoder
for name, param in vae.decoder.named_parameters():
    if 'conv' in name:  # Assuming your convolutional layers have 'conv' in their names
        param.requires_grad = False

# %%
start_time=time.time()

optimizer = torch.optim.Adam(params=vae.parameters(), lr=hparams['learning_rate'], weight_decay=hparams['weight_decay'])

# This is the number of parameters used in the model
num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print(f'Number of parameters: {num_params}')

# set to training mode
vae.train()

train_loss_avg = {"elbo": [], "likelihood": [], "kl_div": []}
val_loss_avg = {"elbo": [], "likelihood": [], "kl_div": []}

print('Training ...')
for epoch in range(hparams['num_epochs']):
    train_loss_avg["elbo"].append(0)
    train_loss_avg["likelihood"].append(0)
    train_loss_avg["kl_div"].append(0)
    num_batches = 0

    for i,(image_batch,_) in enumerate(train_dataloader):

        elbo_loss, likelihood, kl_div = train_batch(image_batch, vae, vae_loss, optimizer)
        train_loss_avg["elbo"][-1] += elbo_loss
        train_loss_avg["likelihood"][-1] += likelihood
        train_loss_avg["kl_div"][-1] += kl_div

    train_loss_avg["elbo"][-1] /= i
    train_loss_avg["likelihood"][-1] /= i
    train_loss_avg["kl_div"][-1] /= i

    print(
        f"Epoch [{epoch + 1} / {hparams['num_epochs']}] Training ELBO loss: {train_loss_avg['elbo'][-1]:.4f}, "
        f"Likelihood loss: {train_loss_avg['likelihood'][-1]:.4f}, "
        f"KL divergence loss: {train_loss_avg['kl_div'][-1]:.4f}"
    )

    # Set to validation mode
    vae.eval()
    with torch.no_grad():
        val_loss_avg["elbo"].append(0)
        val_loss_avg["likelihood"].append(0)
        val_loss_avg["kl_div"].append(0)

        for i, (x_val_batch, _) in enumerate(val_dataloader):
            x_val_batch = x_val_batch.to(device)
            x_val_batch_recon, latent_mu, latent_logvar = vae(x_val_batch)
            val_elbo_loss, val_likelihood, val_kl_div = vae_loss(x_val_batch_recon, x_val_batch, latent_mu, latent_logvar)
            val_loss_avg["elbo"][-1] += val_elbo_loss.item()
            val_loss_avg["likelihood"][-1] += val_likelihood.item()
            val_loss_avg["kl_div"][-1] += val_kl_div.item()

        val_loss_avg["elbo"][-1] /= i
        val_loss_avg["likelihood"][-1] /= i
        val_loss_avg["kl_div"][-1] /= i

        print(
            f"Epoch [{epoch + 1} / {hparams['num_epochs']}] Validation ELBO loss: {val_loss_avg['elbo'][-1]:.4f}, "
            f"Likelihood loss: {val_loss_avg['likelihood'][-1]:.4f}, "
            f"KL divergence loss: {val_loss_avg['kl_div'][-1]:.4f}"
        )
    vae.train()

print("--- TOTAL TIME: %s min ---" % (round((time.time() - start_time) / 60, 3)))
# Out:
# Number of parameters: 3997324
# Training ...
# Epoch [1 / 300] Training ELBO loss: 281.9471, Likelihood loss: 28997.3207, KL divergence loss: 7091.9072
# Epoch [1 / 300] Validation ELBO loss: 426.9576, Likelihood loss: 41666.0527, KL divergence loss: 12984.5156
# Epoch [2 / 300] Training ELBO loss: 239.7007, Likelihood loss: 23164.4373, KL divergence loss: 7517.2566
# Epoch [2 / 300] Validation ELBO loss: 372.9740, Likelihood loss: 33944.0020, KL divergence loss: 13796.6714
# Epoch [3 / 300] Training ELBO loss: 212.8675, Likelihood loss: 19265.4422, KL divergence loss: 7981.5987
# Epoch [3 / 300] Validation ELBO loss: 337.0161, Likelihood loss: 28581.5234, KL divergence loss: 14556.5386
# Epoch [4 / 300] Training ELBO loss: 191.6631, Likelihood loss: 16183.3817, KL divergence loss: 8349.4994
# Epoch [4 / 300] Validation ELBO loss: 302.7197, Likelihood loss: 23612.3389, KL divergence loss: 15135.7798
# Epoch [5 / 300] Training ELBO loss: 176.7737, Likelihood loss: 14065.7197, KL divergence loss: 8561.3126
# Epoch [5 / 300] Validation ELBO loss: 287.1685, Likelihood loss: 21277.8730, KL divergence loss: 15479.7017
# Epoch [6 / 300] Training ELBO loss: 166.5118, Likelihood loss: 12576.3039, KL divergence loss: 8737.2031
# Epoch [6 / 300] Validation ELBO loss: 272.1114, Likelihood loss: 19328.0352, KL divergence loss: 15502.2222
# Epoch [7 / 300] Training ELBO loss: 159.4665, Likelihood loss: 11735.7493, KL divergence loss: 8675.9604
# Epoch [7 / 300] Validation ELBO loss: 264.2598, Likelihood loss: 18634.8691, KL divergence loss: 15190.3916
# Epoch [8 / 300] Training ELBO loss: 154.3177, Likelihood loss: 11363.9486, KL divergence loss: 8388.7109
# Epoch [8 / 300] Validation ELBO loss: 257.0785, Likelihood loss: 18155.5537, KL divergence loss: 14750.4946
# Epoch [9 / 300] Training ELBO loss: 149.1141, Likelihood loss: 10894.9809, KL divergence loss: 8191.6239
# Epoch [9 / 300] Validation ELBO loss: 250.3824, Likelihood loss: 17768.0771, KL divergence loss: 14280.8633
# Epoch [10 / 300] Training ELBO loss: 146.3785, Likelihood loss: 10814.8784, KL divergence loss: 7921.5741
# Epoch [10 / 300] Validation ELBO loss: 245.8477, Likelihood loss: 17638.6143, KL divergence loss: 13829.8955
# Epoch [11 / 300] Training ELBO loss: 143.6730, Likelihood loss: 10711.4061, KL divergence loss: 7678.7413
# Epoch [11 / 300] Validation ELBO loss: 242.1180, Likelihood loss: 17586.9102, KL divergence loss: 13404.1899
# Epoch [12 / 300] Training ELBO loss: 141.5737, Likelihood loss: 10677.5939, KL divergence loss: 7443.8382
# Epoch [12 / 300] Validation ELBO loss: 235.8540, Likelihood loss: 17111.4238, KL divergence loss: 13077.8848
# Epoch [13 / 300] Training ELBO loss: 139.7754, Likelihood loss: 10615.5799, KL divergence loss: 7275.6751
# Epoch [13 / 300] Validation ELBO loss: 235.1329, Likelihood loss: 17308.6943, KL divergence loss: 12788.3115
# Epoch [14 / 300] Training ELBO loss: 136.9501, Likelihood loss: 10434.3000, KL divergence loss: 7095.3170
# Epoch [14 / 300] Validation ELBO loss: 231.6503, Likelihood loss: 17115.8047, KL divergence loss: 12535.4346
# Epoch [15 / 300] Training ELBO loss: 135.4628, Likelihood loss: 10353.1253, KL divergence loss: 6986.1145
# Epoch [15 / 300] Validation ELBO loss: 225.2279, Likelihood loss: 16545.5122, KL divergence loss: 12283.6562
# Epoch [16 / 300] Training ELBO loss: 133.9043, Likelihood loss: 10294.8074, KL divergence loss: 6844.9424
# Epoch [16 / 300] Validation ELBO loss: 227.5029, Likelihood loss: 17061.9980, KL divergence loss: 12058.3682
# Epoch [17 / 300] Training ELBO loss: 132.5460, Likelihood loss: 10265.0481, KL divergence loss: 6700.8360
# Epoch [17 / 300] Validation ELBO loss: 224.6373, Likelihood loss: 16882.0449, KL divergence loss: 11871.5244
# Epoch [18 / 300] Training ELBO loss: 131.2648, Likelihood loss: 10192.4699, KL divergence loss: 6609.4263
# Epoch [18 / 300] Validation ELBO loss: 223.0358, Likelihood loss: 16824.6133, KL divergence loss: 11723.9639
# Epoch [19 / 300] Training ELBO loss: 130.4335, Likelihood loss: 10166.7031, KL divergence loss: 6528.7894
# Epoch [19 / 300] Validation ELBO loss: 221.1400, Likelihood loss: 16812.5293, KL divergence loss: 11493.3872
# Epoch [20 / 300] Training ELBO loss: 127.9181, Likelihood loss: 9986.0214, KL divergence loss: 6387.4889
# Epoch [20 / 300] Validation ELBO loss: 220.8760, Likelihood loss: 17010.3857, KL divergence loss: 11261.7441
# Epoch [21 / 300] Training ELBO loss: 126.7880, Likelihood loss: 9966.1483, KL divergence loss: 6262.7197
# Epoch [21 / 300] Validation ELBO loss: 217.3411, Likelihood loss: 16793.8027, KL divergence loss: 11025.8643
# Epoch [22 / 300] Training ELBO loss: 126.4585, Likelihood loss: 10029.5102, KL divergence loss: 6157.1766
# Epoch [22 / 300] Validation ELBO loss: 214.9894, Likelihood loss: 16662.2705, KL divergence loss: 10856.3774
# Epoch [23 / 300] Training ELBO loss: 126.0412, Likelihood loss: 10048.0195, KL divergence loss: 6085.2516
# Epoch [23 / 300] Validation ELBO loss: 214.5182, Likelihood loss: 16624.6377, KL divergence loss: 10833.6914
# Epoch [24 / 300] Training ELBO loss: 124.4843, Likelihood loss: 9847.1487, KL divergence loss: 6086.8449
# Epoch [24 / 300] Validation ELBO loss: 213.2868, Likelihood loss: 16577.9844, KL divergence loss: 10722.7217
# Epoch [25 / 300] Training ELBO loss: 123.7584, Likelihood loss: 9851.4915, KL divergence loss: 5989.5886
# Epoch [25 / 300] Validation ELBO loss: 211.6019, Likelihood loss: 16532.6904, KL divergence loss: 10552.3516
# Epoch [26 / 300] Training ELBO loss: 123.1493, Likelihood loss: 9860.9035, KL divergence loss: 5902.2071
# Epoch [26 / 300] Validation ELBO loss: 209.2155, Likelihood loss: 16328.0601, KL divergence loss: 10451.5259
# Epoch [27 / 300] Training ELBO loss: 122.0179, Likelihood loss: 9772.5846, KL divergence loss: 5845.7063
# Epoch [27 / 300] Validation ELBO loss: 209.4929, Likelihood loss: 16516.3008, KL divergence loss: 10298.7881
# Epoch [28 / 300] Training ELBO loss: 121.4549, Likelihood loss: 9813.3186, KL divergence loss: 5732.9034
# Epoch [28 / 300] Validation ELBO loss: 208.2543, Likelihood loss: 16495.4111, KL divergence loss: 10161.1357
# Epoch [29 / 300] Training ELBO loss: 120.5414, Likelihood loss: 9722.9851, KL divergence loss: 5706.3123
# Epoch [29 / 300] Validation ELBO loss: 204.9559, Likelihood loss: 16154.5830, KL divergence loss: 10079.7764
# Epoch [30 / 300] Training ELBO loss: 120.2620, Likelihood loss: 9728.4743, KL divergence loss: 5665.0600
# Epoch [30 / 300] Validation ELBO loss: 205.6123, Likelihood loss: 16367.2148, KL divergence loss: 9951.1616
# Epoch [31 / 300] Training ELBO loss: 118.9744, Likelihood loss: 9667.9672, KL divergence loss: 5560.7519
# Epoch [31 / 300] Validation ELBO loss: 204.2555, Likelihood loss: 16280.4595, KL divergence loss: 9864.2388
# Epoch [32 / 300] Training ELBO loss: 118.1929, Likelihood loss: 9624.5067, KL divergence loss: 5504.1792
# Epoch [32 / 300] Validation ELBO loss: 203.7258, Likelihood loss: 16280.9795, KL divergence loss: 9795.9224
# Epoch [33 / 300] Training ELBO loss: 118.3728, Likelihood loss: 9630.4371, KL divergence loss: 5521.2836
# Epoch [33 / 300] Validation ELBO loss: 202.0848, Likelihood loss: 16107.6816, KL divergence loss: 9759.1685
# Epoch [34 / 300] Training ELBO loss: 117.4946, Likelihood loss: 9568.6401, KL divergence loss: 5470.6650
# Epoch [34 / 300] Validation ELBO loss: 201.0100, Likelihood loss: 16016.3413, KL divergence loss: 9712.9365
# Epoch [35 / 300] Training ELBO loss: 116.7810, Likelihood loss: 9537.6783, KL divergence loss: 5410.2961
# Epoch [35 / 300] Validation ELBO loss: 201.2857, Likelihood loss: 16194.4341, KL divergence loss: 9570.1304
# Epoch [36 / 300] Training ELBO loss: 116.6049, Likelihood loss: 9575.8559, KL divergence loss: 5349.5683
# Epoch [36 / 300] Validation ELBO loss: 200.0468, Likelihood loss: 16101.2637, KL divergence loss: 9504.7266
# Epoch [37 / 300] Training ELBO loss: 116.0261, Likelihood loss: 9524.8217, KL divergence loss: 5326.5203
# Epoch [37 / 300] Validation ELBO loss: 198.3673, Likelihood loss: 15888.6025, KL divergence loss: 9502.4072
# Epoch [38 / 300] Training ELBO loss: 115.0413, Likelihood loss: 9419.1857, KL divergence loss: 5306.1013
# Epoch [38 / 300] Validation ELBO loss: 198.7928, Likelihood loss: 16065.9717, KL divergence loss: 9379.5020
# Epoch [39 / 300] Training ELBO loss: 114.8323, Likelihood loss: 9456.7467, KL divergence loss: 5241.7853
# Epoch [39 / 300] Validation ELBO loss: 198.9851, Likelihood loss: 16209.0923, KL divergence loss: 9261.0059
# Epoch [40 / 300] Training ELBO loss: 114.1584, Likelihood loss: 9411.7285, KL divergence loss: 5200.5481
# Epoch [40 / 300] Validation ELBO loss: 194.5331, Likelihood loss: 15704.9224, KL divergence loss: 9195.3135
# Epoch [41 / 300] Training ELBO loss: 113.4907, Likelihood loss: 9345.6864, KL divergence loss: 5181.1286
# Epoch [41 / 300] Validation ELBO loss: 194.7134, Likelihood loss: 15773.8916, KL divergence loss: 9149.4204
# Epoch [42 / 300] Training ELBO loss: 113.7637, Likelihood loss: 9437.5795, KL divergence loss: 5124.1697
# Epoch [42 / 300] Validation ELBO loss: 197.8298, Likelihood loss: 16269.7764, KL divergence loss: 9052.4375
# Epoch [43 / 300] Training ELBO loss: 112.9518, Likelihood loss: 9373.9441, KL divergence loss: 5083.8805
# Epoch [43 / 300] Validation ELBO loss: 194.5973, Likelihood loss: 15883.0366, KL divergence loss: 9025.4180
# Epoch [44 / 300] Training ELBO loss: 112.4985, Likelihood loss: 9344.0219, KL divergence loss: 5055.7893
# Epoch [44 / 300] Validation ELBO loss: 194.1357, Likelihood loss: 15827.8921, KL divergence loss: 9021.4717
# Epoch [45 / 300] Training ELBO loss: 112.1814, Likelihood loss: 9317.1081, KL divergence loss: 5042.1133
# Epoch [45 / 300] Validation ELBO loss: 193.3611, Likelihood loss: 15844.8096, KL divergence loss: 8905.4062
# Epoch [46 / 300] Training ELBO loss: 112.1798, Likelihood loss: 9391.2750, KL divergence loss: 4967.7395
# Epoch [46 / 300] Validation ELBO loss: 190.5643, Likelihood loss: 15550.3008, KL divergence loss: 8841.9263
# Epoch [47 / 300] Training ELBO loss: 111.3323, Likelihood loss: 9296.4389, KL divergence loss: 4954.0896
# Epoch [47 / 300] Validation ELBO loss: 192.6783, Likelihood loss: 15831.4712, KL divergence loss: 8831.3501
# Epoch [48 / 300] Training ELBO loss: 110.6296, Likelihood loss: 9205.6572, KL divergence loss: 4954.9369
# Epoch [48 / 300] Validation ELBO loss: 191.3649, Likelihood loss: 15731.3828, KL divergence loss: 8763.3271
# Epoch [49 / 300] Training ELBO loss: 111.0230, Likelihood loss: 9311.0022, KL divergence loss: 4899.9467
# Epoch [49 / 300] Validation ELBO loss: 190.0331, Likelihood loss: 15638.0923, KL divergence loss: 8686.1494
# Epoch [50 / 300] Training ELBO loss: 109.9518, Likelihood loss: 9213.3725, KL divergence loss: 4860.4638
# Epoch [50 / 300] Validation ELBO loss: 190.9654, Likelihood loss: 15807.1094, KL divergence loss: 8636.4678
# Epoch [51 / 300] Training ELBO loss: 109.5214, Likelihood loss: 9178.9892, KL divergence loss: 4839.7480
# Epoch [51 / 300] Validation ELBO loss: 190.0186, Likelihood loss: 15686.4375, KL divergence loss: 8635.9434
# Epoch [52 / 300] Training ELBO loss: 109.6042, Likelihood loss: 9196.7944, KL divergence loss: 4832.5478
# Epoch [52 / 300] Validation ELBO loss: 190.4471, Likelihood loss: 15847.9688, KL divergence loss: 8529.2598
# Epoch [53 / 300] Training ELBO loss: 108.8842, Likelihood loss: 9151.9423, KL divergence loss: 4785.2312
# Epoch [53 / 300] Validation ELBO loss: 189.6774, Likelihood loss: 15800.6416, KL divergence loss: 8478.0615
# Epoch [54 / 300] Training ELBO loss: 108.4057, Likelihood loss: 9108.5897, KL divergence loss: 4767.3351
# Epoch [54 / 300] Validation ELBO loss: 189.5439, Likelihood loss: 15808.4585, KL divergence loss: 8453.1606
# Epoch [55 / 300] Training ELBO loss: 108.1410, Likelihood loss: 9092.0578, KL divergence loss: 4749.9848
# Epoch [55 / 300] Validation ELBO loss: 190.6925, Likelihood loss: 16008.1675, KL divergence loss: 8400.4692
# Epoch [56 / 300] Training ELBO loss: 107.7878, Likelihood loss: 9077.8799, KL divergence loss: 4718.9602
# Epoch [56 / 300] Validation ELBO loss: 187.8214, Likelihood loss: 15695.5068, KL divergence loss: 8345.6309
# Epoch [57 / 300] Training ELBO loss: 107.4878, Likelihood loss: 9044.4178, KL divergence loss: 4714.0199
# Epoch [57 / 300] Validation ELBO loss: 188.4066, Likelihood loss: 15777.9697, KL divergence loss: 8338.0801
# Epoch [58 / 300] Training ELBO loss: 108.0064, Likelihood loss: 9113.2487, KL divergence loss: 4711.5652
# Epoch [58 / 300] Validation ELBO loss: 185.2041, Likelihood loss: 15370.2344, KL divergence loss: 8335.8857
# Epoch [59 / 300] Training ELBO loss: 107.1743, Likelihood loss: 9047.3813, KL divergence loss: 4670.9327
# Epoch [59 / 300] Validation ELBO loss: 187.7206, Likelihood loss: 15757.2417, KL divergence loss: 8270.9980
# Epoch [60 / 300] Training ELBO loss: 106.6963, Likelihood loss: 9042.0140, KL divergence loss: 4615.1135
# Epoch [60 / 300] Validation ELBO loss: 186.3772, Likelihood loss: 15676.5454, KL divergence loss: 8179.7397
# Epoch [61 / 300] Training ELBO loss: 106.7957, Likelihood loss: 9092.0739, KL divergence loss: 4577.7772
# Epoch [61 / 300] Validation ELBO loss: 186.2458, Likelihood loss: 15641.7881, KL divergence loss: 8197.6780
# Epoch [62 / 300] Training ELBO loss: 105.9454, Likelihood loss: 8969.3168, KL divergence loss: 4591.6905
# Epoch [62 / 300] Validation ELBO loss: 185.8133, Likelihood loss: 15617.1343, KL divergence loss: 8166.9622
# Epoch [63 / 300] Training ELBO loss: 105.9667, Likelihood loss: 8997.1700, KL divergence loss: 4566.5624
# Epoch [63 / 300] Validation ELBO loss: 186.7741, Likelihood loss: 15863.3662, KL divergence loss: 8043.7156
# Epoch [64 / 300] Training ELBO loss: 105.7486, Likelihood loss: 9029.3003, KL divergence loss: 4506.5154
# Epoch [64 / 300] Validation ELBO loss: 184.4261, Likelihood loss: 15534.8818, KL divergence loss: 8071.6606
# Epoch [65 / 300] Training ELBO loss: 106.2089, Likelihood loss: 9028.8815, KL divergence loss: 4565.8632
# Epoch [65 / 300] Validation ELBO loss: 186.3437, Likelihood loss: 15671.6816, KL divergence loss: 8180.3096
# Epoch [66 / 300] Training ELBO loss: 105.1013, Likelihood loss: 8879.2784, KL divergence loss: 4573.6938
# Epoch [66 / 300] Validation ELBO loss: 181.3760, Likelihood loss: 15171.1851, KL divergence loss: 8044.9478
# Epoch [67 / 300] Training ELBO loss: 104.5245, Likelihood loss: 8885.8671, KL divergence loss: 4493.2640
# Epoch [67 / 300] Validation ELBO loss: 182.8379, Likelihood loss: 15423.4531, KL divergence loss: 7979.8015
# Epoch [68 / 300] Training ELBO loss: 104.5877, Likelihood loss: 8893.8807, KL divergence loss: 4493.3473
# Epoch [68 / 300] Validation ELBO loss: 181.2938, Likelihood loss: 15208.7393, KL divergence loss: 7996.8662
# Epoch [69 / 300] Training ELBO loss: 104.0460, Likelihood loss: 8850.2043, KL divergence loss: 4467.6803
# Epoch [69 / 300] Validation ELBO loss: 181.0357, Likelihood loss: 15265.8657, KL divergence loss: 7906.7087
# Epoch [70 / 300] Training ELBO loss: 104.4514, Likelihood loss: 8932.4327, KL divergence loss: 4437.3461
# Epoch [70 / 300] Validation ELBO loss: 181.5839, Likelihood loss: 15363.2471, KL divergence loss: 7879.4954
# Epoch [71 / 300] Training ELBO loss: 103.8143, Likelihood loss: 8843.1683, KL divergence loss: 4445.0667
# Epoch [71 / 300] Validation ELBO loss: 182.5114, Likelihood loss: 15484.2339, KL divergence loss: 7877.2295
# Epoch [72 / 300] Training ELBO loss: 104.2044, Likelihood loss: 8888.3698, KL divergence loss: 4449.7935
# Epoch [72 / 300] Validation ELBO loss: 183.0231, Likelihood loss: 15537.7207, KL divergence loss: 7889.2363
# Epoch [73 / 300] Training ELBO loss: 103.1460, Likelihood loss: 8778.0512, KL divergence loss: 4424.6393
# Epoch [73 / 300] Validation ELBO loss: 181.1075, Likelihood loss: 15355.2124, KL divergence loss: 7826.5437
# Epoch [74 / 300] Training ELBO loss: 103.6079, Likelihood loss: 8877.5827, KL divergence loss: 4384.2340
# Epoch [74 / 300] Validation ELBO loss: 182.1253, Likelihood loss: 15543.1123, KL divergence loss: 7768.9297
# Epoch [75 / 300] Training ELBO loss: 103.6656, Likelihood loss: 8869.6272, KL divergence loss: 4399.5637
# Epoch [75 / 300] Validation ELBO loss: 181.0830, Likelihood loss: 15326.9346, KL divergence loss: 7851.6929
# Epoch [76 / 300] Training ELBO loss: 103.0614, Likelihood loss: 8789.7178, KL divergence loss: 4402.1395
# Epoch [76 / 300] Validation ELBO loss: 177.9403, Likelihood loss: 15002.7231, KL divergence loss: 7773.6389
# Epoch [77 / 300] Training ELBO loss: 102.5231, Likelihood loss: 8773.8910, KL divergence loss: 4349.0692
# Epoch [77 / 300] Validation ELBO loss: 179.5296, Likelihood loss: 15253.1680, KL divergence loss: 7726.6235
# Epoch [78 / 300] Training ELBO loss: 102.0363, Likelihood loss: 8697.0427, KL divergence loss: 4363.6070
# Epoch [78 / 300] Validation ELBO loss: 178.6794, Likelihood loss: 15175.7324, KL divergence loss: 7695.2275
# Epoch [79 / 300] Training ELBO loss: 102.4714, Likelihood loss: 8803.2470, KL divergence loss: 4313.0882
# Epoch [79 / 300] Validation ELBO loss: 177.9864, Likelihood loss: 15164.9932, KL divergence loss: 7617.2690
# Epoch [80 / 300] Training ELBO loss: 101.2887, Likelihood loss: 8687.4026, KL divergence loss: 4277.5467
# Epoch [80 / 300] Validation ELBO loss: 178.5609, Likelihood loss: 15282.0435, KL divergence loss: 7573.7476
# Epoch [81 / 300] Training ELBO loss: 101.5360, Likelihood loss: 8726.1549, KL divergence loss: 4270.4557
# Epoch [81 / 300] Validation ELBO loss: 176.9876, Likelihood loss: 15041.6128, KL divergence loss: 7612.8027
# Epoch [82 / 300] Training ELBO loss: 101.9803, Likelihood loss: 8766.0428, KL divergence loss: 4287.4417
# Epoch [82 / 300] Validation ELBO loss: 177.8522, Likelihood loss: 15186.6074, KL divergence loss: 7578.4768
# Epoch [83 / 300] Training ELBO loss: 101.1806, Likelihood loss: 8669.0419, KL divergence loss: 4282.0738
# Epoch [83 / 300] Validation ELBO loss: 175.9583, Likelihood loss: 14978.8931, KL divergence loss: 7543.7627
# Epoch [84 / 300] Training ELBO loss: 101.5162, Likelihood loss: 8749.8601, KL divergence loss: 4244.2096
# Epoch [84 / 300] Validation ELBO loss: 177.8402, Likelihood loss: 15185.6812, KL divergence loss: 7577.8701
# Epoch [85 / 300] Training ELBO loss: 101.0321, Likelihood loss: 8655.2469, KL divergence loss: 4276.8580
# Epoch [85 / 300] Validation ELBO loss: 176.8471, Likelihood loss: 15045.6787, KL divergence loss: 7590.7444
# Epoch [86 / 300] Training ELBO loss: 100.5603, Likelihood loss: 8610.0990, KL divergence loss: 4261.6199
# Epoch [86 / 300] Validation ELBO loss: 174.3765, Likelihood loss: 14771.9248, KL divergence loss: 7548.2737
# Epoch [87 / 300] Training ELBO loss: 100.6009, Likelihood loss: 8643.0761, KL divergence loss: 4233.8431
# Epoch [87 / 300] Validation ELBO loss: 175.3799, Likelihood loss: 15018.1138, KL divergence loss: 7430.5176
# Epoch [88 / 300] Training ELBO loss: 100.2233, Likelihood loss: 8630.7012, KL divergence loss: 4197.8845
# Epoch [88 / 300] Validation ELBO loss: 176.2872, Likelihood loss: 15128.4971, KL divergence loss: 7436.2612
# Epoch [89 / 300] Training ELBO loss: 99.6197, Likelihood loss: 8562.5199, KL divergence loss: 4188.7962
# Epoch [89 / 300] Validation ELBO loss: 175.0331, Likelihood loss: 15004.8862, KL divergence loss: 7399.3491
# Epoch [90 / 300] Training ELBO loss: 99.3799, Likelihood loss: 8570.5155, KL divergence loss: 4150.1064
# Epoch [90 / 300] Validation ELBO loss: 177.0057, Likelihood loss: 15284.0820, KL divergence loss: 7372.6436
# Epoch [91 / 300] Training ELBO loss: 99.8090, Likelihood loss: 8612.9163, KL divergence loss: 4162.6315
# Epoch [91 / 300] Validation ELBO loss: 175.9177, Likelihood loss: 15122.6904, KL divergence loss: 7394.7729
# Epoch [92 / 300] Training ELBO loss: 98.8965, Likelihood loss: 8498.7024, KL divergence loss: 4160.0478
# Epoch [92 / 300] Validation ELBO loss: 175.7035, Likelihood loss: 15132.2549, KL divergence loss: 7357.7991
# Epoch [93 / 300] Training ELBO loss: 99.4042, Likelihood loss: 8592.3938, KL divergence loss: 4131.3470
# Epoch [93 / 300] Validation ELBO loss: 176.2335, Likelihood loss: 15230.0479, KL divergence loss: 7327.8430
# Epoch [94 / 300] Training ELBO loss: 98.2132, Likelihood loss: 8443.6078, KL divergence loss: 4127.6770
# Epoch [94 / 300] Validation ELBO loss: 174.8219, Likelihood loss: 15053.9253, KL divergence loss: 7323.2825
# Epoch [95 / 300] Training ELBO loss: 98.4563, Likelihood loss: 8494.9302, KL divergence loss: 4107.4822
# Epoch [95 / 300] Validation ELBO loss: 174.4335, Likelihood loss: 15101.6548, KL divergence loss: 7225.8315
# Epoch [96 / 300] Training ELBO loss: 98.5221, Likelihood loss: 8511.8164, KL divergence loss: 4099.0091
# Epoch [96 / 300] Validation ELBO loss: 174.6971, Likelihood loss: 15098.5244, KL divergence loss: 7262.6992
# Epoch [97 / 300] Training ELBO loss: 98.2796, Likelihood loss: 8503.4680, KL divergence loss: 4076.3224
# Epoch [97 / 300] Validation ELBO loss: 174.1666, Likelihood loss: 15025.3525, KL divergence loss: 7267.9709
# Epoch [98 / 300] Training ELBO loss: 97.8868, Likelihood loss: 8456.6586, KL divergence loss: 4072.8462
# Epoch [98 / 300] Validation ELBO loss: 171.5840, Likelihood loss: 14758.1675, KL divergence loss: 7204.5806
# Epoch [99 / 300] Training ELBO loss: 98.6598, Likelihood loss: 8557.2512, KL divergence loss: 4071.2025
# Epoch [99 / 300] Validation ELBO loss: 175.4978, Likelihood loss: 15291.3613, KL divergence loss: 7172.3579
# Epoch [100 / 300] Training ELBO loss: 98.5041, Likelihood loss: 8559.6641, KL divergence loss: 4048.8571
# Epoch [100 / 300] Validation ELBO loss: 173.4755, Likelihood loss: 14927.0020, KL divergence loss: 7277.8599
# Epoch [101 / 300] Training ELBO loss: 98.3813, Likelihood loss: 8501.1761, KL divergence loss: 4091.6250
# Epoch [101 / 300] Validation ELBO loss: 173.6474, Likelihood loss: 14951.0181, KL divergence loss: 7275.8486
# Epoch [102 / 300] Training ELBO loss: 97.8911, Likelihood loss: 8435.2868, KL divergence loss: 4094.7775
# Epoch [102 / 300] Validation ELBO loss: 171.9452, Likelihood loss: 14782.6914, KL divergence loss: 7226.2927
# Epoch [103 / 300] Training ELBO loss: 97.8220, Likelihood loss: 8426.8352, KL divergence loss: 4094.3860
# Epoch [103 / 300] Validation ELBO loss: 172.6290, Likelihood loss: 14847.9131, KL divergence loss: 7248.5979
# Epoch [104 / 300] Training ELBO loss: 97.2299, Likelihood loss: 8388.5930, KL divergence loss: 4056.8309
# Epoch [104 / 300] Validation ELBO loss: 169.4469, Likelihood loss: 14495.6797, KL divergence loss: 7193.5205
# Epoch [105 / 300] Training ELBO loss: 97.0831, Likelihood loss: 8392.1566, KL divergence loss: 4034.4862
# Epoch [105 / 300] Validation ELBO loss: 175.4358, Likelihood loss: 15347.0210, KL divergence loss: 7108.7595
# Epoch [106 / 300] Training ELBO loss: 97.2582, Likelihood loss: 8431.0906, KL divergence loss: 4017.9651
# Epoch [106 / 300] Validation ELBO loss: 171.5714, Likelihood loss: 14884.5122, KL divergence loss: 7076.6301
# Epoch [107 / 300] Training ELBO loss: 96.4983, Likelihood loss: 8350.4727, KL divergence loss: 4001.3132
# Epoch [107 / 300] Validation ELBO loss: 171.0072, Likelihood loss: 14760.5415, KL divergence loss: 7128.3833
# Epoch [108 / 300] Training ELBO loss: 96.2977, Likelihood loss: 8319.7668, KL divergence loss: 4006.3447
# Epoch [108 / 300] Validation ELBO loss: 173.9337, Likelihood loss: 15247.1514, KL divergence loss: 7016.3655
# Epoch [109 / 300] Training ELBO loss: 96.9902, Likelihood loss: 8450.9732, KL divergence loss: 3963.7747
# Epoch [109 / 300] Validation ELBO loss: 170.7305, Likelihood loss: 14750.9473, KL divergence loss: 7102.5532
# Epoch [110 / 300] Training ELBO loss: 96.0774, Likelihood loss: 8281.0537, KL divergence loss: 4016.8539
# Epoch [110 / 300] Validation ELBO loss: 169.6265, Likelihood loss: 14641.2490, KL divergence loss: 7070.9485
# Epoch [111 / 300] Training ELBO loss: 97.0191, Likelihood loss: 8461.8771, KL divergence loss: 3956.5683
# Epoch [111 / 300] Validation ELBO loss: 170.5221, Likelihood loss: 14869.9707, KL divergence loss: 6956.8574
# Epoch [112 / 300] Training ELBO loss: 96.2873, Likelihood loss: 8391.6190, KL divergence loss: 3933.1518
# Epoch [112 / 300] Validation ELBO loss: 170.7287, Likelihood loss: 14792.5620, KL divergence loss: 7060.7061
# Epoch [113 / 300] Training ELBO loss: 96.8933, Likelihood loss: 8417.5277, KL divergence loss: 3984.8179
# Epoch [113 / 300] Validation ELBO loss: 170.4980, Likelihood loss: 14772.9995, KL divergence loss: 7050.7439
# Epoch [114 / 300] Training ELBO loss: 95.3155, Likelihood loss: 8219.8287, KL divergence loss: 3980.5613
# Epoch [114 / 300] Validation ELBO loss: 172.6583, Likelihood loss: 15119.4229, KL divergence loss: 6980.8376
# Epoch [115 / 300] Training ELBO loss: 95.4831, Likelihood loss: 8309.7070, KL divergence loss: 3912.1326
# Epoch [115 / 300] Validation ELBO loss: 169.2176, Likelihood loss: 14720.3438, KL divergence loss: 6939.5132
# Epoch [116 / 300] Training ELBO loss: 95.6704, Likelihood loss: 8317.3219, KL divergence loss: 3928.4949
# Epoch [116 / 300] Validation ELBO loss: 170.5239, Likelihood loss: 14823.7236, KL divergence loss: 7003.3333
# Epoch [117 / 300] Training ELBO loss: 95.6791, Likelihood loss: 8299.6657, KL divergence loss: 3947.2585
# Epoch [117 / 300] Validation ELBO loss: 171.0272, Likelihood loss: 14900.0142, KL divergence loss: 6991.4678
# Epoch [118 / 300] Training ELBO loss: 95.7942, Likelihood loss: 8327.4433, KL divergence loss: 3934.2112
# Epoch [118 / 300] Validation ELBO loss: 169.2484, Likelihood loss: 14735.6270, KL divergence loss: 6928.1621
# Epoch [119 / 300] Training ELBO loss: 94.3494, Likelihood loss: 8158.6239, KL divergence loss: 3918.0952
# Epoch [119 / 300] Validation ELBO loss: 168.0276, Likelihood loss: 14591.7393, KL divergence loss: 6915.7959
# Epoch [120 / 300] Training ELBO loss: 95.2138, Likelihood loss: 8278.5643, KL divergence loss: 3908.7986
# Epoch [120 / 300] Validation ELBO loss: 167.3849, Likelihood loss: 14553.2568, KL divergence loss: 6872.0137
# Epoch [121 / 300] Training ELBO loss: 94.5588, Likelihood loss: 8213.5657, KL divergence loss: 3889.9654
# Epoch [121 / 300] Validation ELBO loss: 168.8694, Likelihood loss: 14714.7393, KL divergence loss: 6900.5396
# Epoch [122 / 300] Training ELBO loss: 94.5206, Likelihood loss: 8186.0184, KL divergence loss: 3912.6188
# Epoch [122 / 300] Validation ELBO loss: 169.7948, Likelihood loss: 14817.1465, KL divergence loss: 6916.5837
# Epoch [123 / 300] Training ELBO loss: 94.6018, Likelihood loss: 8174.5993, KL divergence loss: 3934.4362
# Epoch [123 / 300] Validation ELBO loss: 169.2810, Likelihood loss: 14724.0088, KL divergence loss: 6943.9604
# Epoch [124 / 300] Training ELBO loss: 94.1904, Likelihood loss: 8152.8113, KL divergence loss: 3903.5600
# Epoch [124 / 300] Validation ELBO loss: 166.8359, Likelihood loss: 14498.3857, KL divergence loss: 6856.6038
# Epoch [125 / 300] Training ELBO loss: 93.7447, Likelihood loss: 8124.2334, KL divergence loss: 3875.0853
# Epoch [125 / 300] Validation ELBO loss: 168.6809, Likelihood loss: 14697.1895, KL divergence loss: 6893.9619
# Epoch [126 / 300] Training ELBO loss: 95.1422, Likelihood loss: 8295.6455, KL divergence loss: 3882.5599
# Epoch [126 / 300] Validation ELBO loss: 168.6308, Likelihood loss: 14762.1406, KL divergence loss: 6822.6008
# Epoch [127 / 300] Training ELBO loss: 93.8877, Likelihood loss: 8150.8172, KL divergence loss: 3866.8054
# Epoch [127 / 300] Validation ELBO loss: 167.0878, Likelihood loss: 14539.5889, KL divergence loss: 6847.6489
# Epoch [128 / 300] Training ELBO loss: 93.5453, Likelihood loss: 8124.4120, KL divergence loss: 3849.3853
# Epoch [128 / 300] Validation ELBO loss: 165.1721, Likelihood loss: 14353.1680, KL divergence loss: 6788.8599
# Epoch [129 / 300] Training ELBO loss: 93.8172, Likelihood loss: 8174.1791, KL divergence loss: 3834.4205
# Epoch [129 / 300] Validation ELBO loss: 167.6866, Likelihood loss: 14651.7261, KL divergence loss: 6812.1650
# Epoch [130 / 300] Training ELBO loss: 93.8084, Likelihood loss: 8139.1898, KL divergence loss: 3868.2791
# Epoch [130 / 300] Validation ELBO loss: 167.9170, Likelihood loss: 14712.6904, KL divergence loss: 6780.6797
# Epoch [131 / 300] Training ELBO loss: 93.1291, Likelihood loss: 8068.4602, KL divergence loss: 3852.0659
# Epoch [131 / 300] Validation ELBO loss: 167.4054, Likelihood loss: 14627.5215, KL divergence loss: 6800.3730
# Epoch [132 / 300] Training ELBO loss: 92.9693, Likelihood loss: 8055.7002, KL divergence loss: 3844.3765
# Epoch [132 / 300] Validation ELBO loss: 165.4579, Likelihood loss: 14467.2046, KL divergence loss: 6711.4072
# Epoch [133 / 300] Training ELBO loss: 93.4068, Likelihood loss: 8158.1118, KL divergence loss: 3797.9581
# Epoch [133 / 300] Validation ELBO loss: 166.6523, Likelihood loss: 14603.7236, KL divergence loss: 6727.7715
# Epoch [134 / 300] Training ELBO loss: 93.2067, Likelihood loss: 8134.2778, KL divergence loss: 3796.1759
# Epoch [134 / 300] Validation ELBO loss: 167.7921, Likelihood loss: 14762.9409, KL divergence loss: 6714.4443
# Epoch [135 / 300] Training ELBO loss: 93.1473, Likelihood loss: 8133.0526, KL divergence loss: 3789.8040
# Epoch [135 / 300] Validation ELBO loss: 165.7311, Likelihood loss: 14516.7007, KL divergence loss: 6696.8745
# Epoch [136 / 300] Training ELBO loss: 92.9326, Likelihood loss: 8076.2923, KL divergence loss: 3819.0869
# Epoch [136 / 300] Validation ELBO loss: 167.7970, Likelihood loss: 14689.5454, KL divergence loss: 6788.4705
# Epoch [137 / 300] Training ELBO loss: 93.4301, Likelihood loss: 8125.4836, KL divergence loss: 3833.5635
# Epoch [137 / 300] Validation ELBO loss: 164.8824, Likelihood loss: 14335.1558, KL divergence loss: 6769.7939
# Epoch [138 / 300] Training ELBO loss: 92.2140, Likelihood loss: 7991.2907, KL divergence loss: 3812.0971
# Epoch [138 / 300] Validation ELBO loss: 165.9417, Likelihood loss: 14553.0835, KL divergence loss: 6687.4482
# Epoch [139 / 300] Training ELBO loss: 91.9461, Likelihood loss: 7998.7371, KL divergence loss: 3770.3643
# Epoch [139 / 300] Validation ELBO loss: 165.5114, Likelihood loss: 14548.8115, KL divergence loss: 6636.6475
# Epoch [140 / 300] Training ELBO loss: 91.9637, Likelihood loss: 8003.2469, KL divergence loss: 3768.1101
# Epoch [140 / 300] Validation ELBO loss: 162.4427, Likelihood loss: 14093.2539, KL divergence loss: 6699.4133
# Epoch [141 / 300] Training ELBO loss: 92.0466, Likelihood loss: 8004.9695, KL divergence loss: 3776.9973
# Epoch [141 / 300] Validation ELBO loss: 165.2417, Likelihood loss: 14500.6602, KL divergence loss: 6650.2759
# Epoch [142 / 300] Training ELBO loss: 92.2806, Likelihood loss: 8033.6401, KL divergence loss: 3778.2816
# Epoch [142 / 300] Validation ELBO loss: 163.1218, Likelihood loss: 14247.1118, KL divergence loss: 6632.4746
# Epoch [143 / 300] Training ELBO loss: 92.0277, Likelihood loss: 8016.8448, KL divergence loss: 3762.6964
# Epoch [143 / 300] Validation ELBO loss: 163.9990, Likelihood loss: 14344.2910, KL divergence loss: 6647.5833
# Epoch [144 / 300] Training ELBO loss: 92.4611, Likelihood loss: 8076.1333, KL divergence loss: 3758.8854
# Epoch [144 / 300] Validation ELBO loss: 166.9841, Likelihood loss: 14699.9111, KL divergence loss: 6674.0537
# Epoch [145 / 300] Training ELBO loss: 91.5142, Likelihood loss: 7919.2450, KL divergence loss: 3794.5701
# Epoch [145 / 300] Validation ELBO loss: 166.5893, Likelihood loss: 14683.9863, KL divergence loss: 6639.4502
# Epoch [146 / 300] Training ELBO loss: 91.9629, Likelihood loss: 8002.7300, KL divergence loss: 3768.5264
# Epoch [146 / 300] Validation ELBO loss: 163.5397, Likelihood loss: 14245.9805, KL divergence loss: 6687.1072
# Epoch [147 / 300] Training ELBO loss: 92.2204, Likelihood loss: 8003.9778, KL divergence loss: 3800.2300
# Epoch [147 / 300] Validation ELBO loss: 163.8716, Likelihood loss: 14237.8418, KL divergence loss: 6737.7246
# Epoch [148 / 300] Training ELBO loss: 91.4588, Likelihood loss: 7915.1499, KL divergence loss: 3791.5801
# Epoch [148 / 300] Validation ELBO loss: 163.8647, Likelihood loss: 14316.7900, KL divergence loss: 6657.8982
# Epoch [149 / 300] Training ELBO loss: 91.4257, Likelihood loss: 7932.9863, KL divergence loss: 3769.5004
# Epoch [149 / 300] Validation ELBO loss: 163.7434, Likelihood loss: 14326.9282, KL divergence loss: 6632.2229
# Epoch [150 / 300] Training ELBO loss: 90.6497, Likelihood loss: 7848.3674, KL divergence loss: 3754.7938
# Epoch [150 / 300] Validation ELBO loss: 165.8615, Likelihood loss: 14610.9204, KL divergence loss: 6619.3472
# Epoch [151 / 300] Training ELBO loss: 90.9926, Likelihood loss: 7907.4033, KL divergence loss: 3739.6507
# Epoch [151 / 300] Validation ELBO loss: 165.1295, Likelihood loss: 14590.1807, KL divergence loss: 6546.3916
# Epoch [152 / 300] Training ELBO loss: 90.7015, Likelihood loss: 7878.9747, KL divergence loss: 3730.8212
# Epoch [152 / 300] Validation ELBO loss: 164.0950, Likelihood loss: 14399.4243, KL divergence loss: 6604.7375
# Epoch [153 / 300] Training ELBO loss: 91.4442, Likelihood loss: 7947.3092, KL divergence loss: 3757.5468
# Epoch [153 / 300] Validation ELBO loss: 163.2845, Likelihood loss: 14212.7017, KL divergence loss: 6687.7144
# Epoch [154 / 300] Training ELBO loss: 90.8001, Likelihood loss: 7849.4088, KL divergence loss: 3773.0008
# Epoch [154 / 300] Validation ELBO loss: 163.4569, Likelihood loss: 14313.4697, KL divergence loss: 6609.0134
# Epoch [155 / 300] Training ELBO loss: 91.0464, Likelihood loss: 7929.4919, KL divergence loss: 3724.4483
# Epoch [155 / 300] Validation ELBO loss: 163.0069, Likelihood loss: 14314.6489, KL divergence loss: 6550.2393
# Epoch [156 / 300] Training ELBO loss: 90.4355, Likelihood loss: 7861.5343, KL divergence loss: 3714.2094
# Epoch [156 / 300] Validation ELBO loss: 167.1624, Likelihood loss: 14831.3804, KL divergence loss: 6565.4126
# Epoch [157 / 300] Training ELBO loss: 90.2043, Likelihood loss: 7831.3171, KL divergence loss: 3714.8393
# Epoch [157 / 300] Validation ELBO loss: 163.9049, Likelihood loss: 14470.5679, KL divergence loss: 6509.2568
# Epoch [158 / 300] Training ELBO loss: 90.7380, Likelihood loss: 7954.8539, KL divergence loss: 3659.6098
# Epoch [158 / 300] Validation ELBO loss: 161.8050, Likelihood loss: 14178.4224, KL divergence loss: 6532.6133
# Epoch [159 / 300] Training ELBO loss: 90.7588, Likelihood loss: 7920.0522, KL divergence loss: 3697.0801
# Epoch [159 / 300] Validation ELBO loss: 163.6105, Likelihood loss: 14417.1479, KL divergence loss: 6524.9961
# Epoch [160 / 300] Training ELBO loss: 90.8718, Likelihood loss: 7930.4891, KL divergence loss: 3701.1002
# Epoch [160 / 300] Validation ELBO loss: 164.4648, Likelihood loss: 14477.4189, KL divergence loss: 6574.0703
# Epoch [161 / 300] Training ELBO loss: 90.1108, Likelihood loss: 7801.2942, KL divergence loss: 3732.8930
# Epoch [161 / 300] Validation ELBO loss: 161.4222, Likelihood loss: 14085.4478, KL divergence loss: 6576.5896
# Epoch [162 / 300] Training ELBO loss: 90.6493, Likelihood loss: 7874.3085, KL divergence loss: 3728.7955
# Epoch [162 / 300] Validation ELBO loss: 162.0530, Likelihood loss: 14154.5039, KL divergence loss: 6588.2820
# Epoch [163 / 300] Training ELBO loss: 89.8264, Likelihood loss: 7778.7833, KL divergence loss: 3719.0020
# Epoch [163 / 300] Validation ELBO loss: 162.7099, Likelihood loss: 14307.4746, KL divergence loss: 6519.3940
# Epoch [164 / 300] Training ELBO loss: 89.8550, Likelihood loss: 7816.0418, KL divergence loss: 3685.3942
# Epoch [164 / 300] Validation ELBO loss: 162.0446, Likelihood loss: 14176.7305, KL divergence loss: 6564.9773
# Epoch [165 / 300] Training ELBO loss: 90.2324, Likelihood loss: 7816.0163, KL divergence loss: 3733.7341
# Epoch [165 / 300] Validation ELBO loss: 162.9268, Likelihood loss: 14323.5508, KL divergence loss: 6531.0859
# Epoch [166 / 300] Training ELBO loss: 90.1636, Likelihood loss: 7832.0709, KL divergence loss: 3708.8765
# Epoch [166 / 300] Validation ELBO loss: 162.1534, Likelihood loss: 14220.8682, KL divergence loss: 6534.7668
# Epoch [167 / 300] Training ELBO loss: 90.1195, Likelihood loss: 7808.0974, KL divergence loss: 3727.2043
# Epoch [167 / 300] Validation ELBO loss: 161.8733, Likelihood loss: 14094.2607, KL divergence loss: 6625.5249
# Epoch [168 / 300] Training ELBO loss: 89.7982, Likelihood loss: 7779.2112, KL divergence loss: 3714.9606
# Epoch [168 / 300] Validation ELBO loss: 161.2940, Likelihood loss: 14124.8350, KL divergence loss: 6520.7986
# Epoch [169 / 300] Training ELBO loss: 89.1109, Likelihood loss: 7701.3803, KL divergence loss: 3704.8100
# Epoch [169 / 300] Validation ELBO loss: 162.1479, Likelihood loss: 14214.6509, KL divergence loss: 6540.2856
# Epoch [170 / 300] Training ELBO loss: 88.8591, Likelihood loss: 7673.2973, KL divergence loss: 3700.6711
# Epoch [170 / 300] Validation ELBO loss: 160.1796, Likelihood loss: 14026.3027, KL divergence loss: 6476.6797
# Epoch [171 / 300] Training ELBO loss: 89.0380, Likelihood loss: 7756.4022, KL divergence loss: 3640.4666
# Epoch [171 / 300] Validation ELBO loss: 161.8363, Likelihood loss: 14314.2324, KL divergence loss: 6400.8167
# Epoch [172 / 300] Training ELBO loss: 89.0028, Likelihood loss: 7738.5584, KL divergence loss: 3653.7976
# Epoch [172 / 300] Validation ELBO loss: 161.7946, Likelihood loss: 14261.5762, KL divergence loss: 6448.1306
# Epoch [173 / 300] Training ELBO loss: 88.8632, Likelihood loss: 7716.5323, KL divergence loss: 3657.9606
# Epoch [173 / 300] Validation ELBO loss: 160.1551, Likelihood loss: 14073.2373, KL divergence loss: 6426.6150
# Epoch [174 / 300] Training ELBO loss: 89.2180, Likelihood loss: 7793.0598, KL divergence loss: 3626.8452
# Epoch [174 / 300] Validation ELBO loss: 161.1024, Likelihood loss: 14232.4766, KL divergence loss: 6388.6270
# Epoch [175 / 300] Training ELBO loss: 88.6456, Likelihood loss: 7687.8184, KL divergence loss: 3658.8220
# Epoch [175 / 300] Validation ELBO loss: 160.0706, Likelihood loss: 14002.9824, KL divergence loss: 6486.0596
# Epoch [176 / 300] Training ELBO loss: 88.5474, Likelihood loss: 7662.4161, KL divergence loss: 3671.6525
# Epoch [176 / 300] Validation ELBO loss: 160.7355, Likelihood loss: 14171.0742, KL divergence loss: 6403.0659
# Epoch [177 / 300] Training ELBO loss: 88.0796, Likelihood loss: 7656.5198, KL divergence loss: 3617.6659
# Epoch [177 / 300] Validation ELBO loss: 159.2272, Likelihood loss: 13993.4116, KL divergence loss: 6387.6667
# Epoch [178 / 300] Training ELBO loss: 88.4103, Likelihood loss: 7693.0039, KL divergence loss: 3623.5097
# Epoch [178 / 300] Validation ELBO loss: 160.3666, Likelihood loss: 14133.2939, KL divergence loss: 6393.6370
# Epoch [179 / 300] Training ELBO loss: 88.8143, Likelihood loss: 7773.9595, KL divergence loss: 3594.2703
# Epoch [179 / 300] Validation ELBO loss: 159.2401, Likelihood loss: 14090.0557, KL divergence loss: 6292.6772
# Epoch [180 / 300] Training ELBO loss: 87.9790, Likelihood loss: 7685.4242, KL divergence loss: 3575.8847
# Epoch [180 / 300] Validation ELBO loss: 161.8316, Likelihood loss: 14347.6851, KL divergence loss: 6366.7554
# Epoch [181 / 300] Training ELBO loss: 88.1011, Likelihood loss: 7651.1302, KL divergence loss: 3625.8148
# Epoch [181 / 300] Validation ELBO loss: 159.7216, Likelihood loss: 14048.7627, KL divergence loss: 6395.5994
# Epoch [182 / 300] Training ELBO loss: 88.4871, Likelihood loss: 7712.9287, KL divergence loss: 3613.4261
# Epoch [182 / 300] Validation ELBO loss: 158.7292, Likelihood loss: 13963.7056, KL divergence loss: 6353.6353
# Epoch [183 / 300] Training ELBO loss: 87.4702, Likelihood loss: 7577.1593, KL divergence loss: 3619.0293
# Epoch [183 / 300] Validation ELBO loss: 162.6264, Likelihood loss: 14418.9097, KL divergence loss: 6397.2683
# Epoch [184 / 300] Training ELBO loss: 87.8328, Likelihood loss: 7611.1300, KL divergence loss: 3631.4698
# Epoch [184 / 300] Validation ELBO loss: 157.4468, Likelihood loss: 13808.9204, KL divergence loss: 6344.2729
# Epoch [185 / 300] Training ELBO loss: 88.1088, Likelihood loss: 7650.6902, KL divergence loss: 3627.2370
# Epoch [185 / 300] Validation ELBO loss: 158.6290, Likelihood loss: 13908.6958, KL divergence loss: 6395.8157
# Epoch [186 / 300] Training ELBO loss: 87.5962, Likelihood loss: 7595.2250, KL divergence loss: 3617.0845
# Epoch [186 / 300] Validation ELBO loss: 161.7536, Likelihood loss: 14356.1089, KL divergence loss: 6348.3552
# Epoch [187 / 300] Training ELBO loss: 87.9415, Likelihood loss: 7646.7024, KL divergence loss: 3609.8141
# Epoch [187 / 300] Validation ELBO loss: 157.4289, Likelihood loss: 13770.9307, KL divergence loss: 6379.9629
# Epoch [188 / 300] Training ELBO loss: 87.7536, Likelihood loss: 7622.0143, KL divergence loss: 3610.4478
# Epoch [188 / 300] Validation ELBO loss: 159.7657, Likelihood loss: 14101.3413, KL divergence loss: 6348.6624
# Epoch [189 / 300] Training ELBO loss: 87.6409, Likelihood loss: 7611.8177, KL divergence loss: 3606.2223
# Epoch [189 / 300] Validation ELBO loss: 159.9973, Likelihood loss: 14171.1719, KL divergence loss: 6308.4824
# Epoch [190 / 300] Training ELBO loss: 87.8545, Likelihood loss: 7631.4469, KL divergence loss: 3613.9316
# Epoch [190 / 300] Validation ELBO loss: 161.6201, Likelihood loss: 14221.9736, KL divergence loss: 6465.3975
# Epoch [191 / 300] Training ELBO loss: 87.2025, Likelihood loss: 7515.4258, KL divergence loss: 3646.5001
# Epoch [191 / 300] Validation ELBO loss: 159.8509, Likelihood loss: 14161.1328, KL divergence loss: 6299.7759
# Epoch [192 / 300] Training ELBO loss: 86.6813, Likelihood loss: 7529.4657, KL divergence loss: 3565.7380
# Epoch [192 / 300] Validation ELBO loss: 158.5935, Likelihood loss: 14047.9570, KL divergence loss: 6252.0151
# Epoch [193 / 300] Training ELBO loss: 87.0318, Likelihood loss: 7579.6421, KL divergence loss: 3560.4227
# Epoch [193 / 300] Validation ELBO loss: 157.4805, Likelihood loss: 13817.0249, KL divergence loss: 6340.4805
# Epoch [194 / 300] Training ELBO loss: 86.5236, Likelihood loss: 7491.0623, KL divergence loss: 3583.9539
# Epoch [194 / 300] Validation ELBO loss: 157.9410, Likelihood loss: 13946.3369, KL divergence loss: 6270.1145
# Epoch [195 / 300] Training ELBO loss: 86.9579, Likelihood loss: 7584.7123, KL divergence loss: 3545.8977
# Epoch [195 / 300] Validation ELBO loss: 160.4648, Likelihood loss: 14273.7173, KL divergence loss: 6265.7783
# Epoch [196 / 300] Training ELBO loss: 87.7936, Likelihood loss: 7640.0703, KL divergence loss: 3597.5045
# Epoch [196 / 300] Validation ELBO loss: 159.9366, Likelihood loss: 14099.0972, KL divergence loss: 6372.7944
# Epoch [197 / 300] Training ELBO loss: 86.4060, Likelihood loss: 7451.1941, KL divergence loss: 3608.7788
# Epoch [197 / 300] Validation ELBO loss: 158.9493, Likelihood loss: 14079.4033, KL divergence loss: 6266.1113
# Epoch [198 / 300] Training ELBO loss: 86.7392, Likelihood loss: 7561.0944, KL divergence loss: 3541.5278
# Epoch [198 / 300] Validation ELBO loss: 158.0563, Likelihood loss: 13959.0522, KL divergence loss: 6272.1521
# Epoch [199 / 300] Training ELBO loss: 86.5754, Likelihood loss: 7513.0316, KL divergence loss: 3568.6160
# Epoch [199 / 300] Validation ELBO loss: 155.5300, Likelihood loss: 13612.9351, KL divergence loss: 6294.8989
# Epoch [200 / 300] Training ELBO loss: 86.7841, Likelihood loss: 7546.9471, KL divergence loss: 3561.4163
# Epoch [200 / 300] Validation ELBO loss: 158.0935, Likelihood loss: 13978.6265, KL divergence loss: 6257.3477
# Epoch [201 / 300] Training ELBO loss: 86.4648, Likelihood loss: 7523.4741, KL divergence loss: 3544.0219
# Epoch [201 / 300] Validation ELBO loss: 158.1244, Likelihood loss: 13964.0337, KL divergence loss: 6275.8853
# Epoch [202 / 300] Training ELBO loss: 86.1496, Likelihood loss: 7438.0065, KL divergence loss: 3589.1370
# Epoch [202 / 300] Validation ELBO loss: 157.7134, Likelihood loss: 13914.5444, KL divergence loss: 6272.7712
# Epoch [203 / 300] Training ELBO loss: 86.1514, Likelihood loss: 7474.2348, KL divergence loss: 3553.1462
# Epoch [203 / 300] Validation ELBO loss: 155.5343, Likelihood loss: 13656.9766, KL divergence loss: 6251.4109
# Epoch [204 / 300] Training ELBO loss: 86.7421, Likelihood loss: 7541.8987, KL divergence loss: 3561.0855
# Epoch [204 / 300] Validation ELBO loss: 157.5141, Likelihood loss: 13860.7236, KL divergence loss: 6301.0815
# Epoch [205 / 300] Training ELBO loss: 86.2916, Likelihood loss: 7464.8285, KL divergence loss: 3580.5021
# Epoch [205 / 300] Validation ELBO loss: 156.4029, Likelihood loss: 13714.3281, KL divergence loss: 6305.2466
# Epoch [206 / 300] Training ELBO loss: 86.4014, Likelihood loss: 7477.3679, KL divergence loss: 3582.0151
# Epoch [206 / 300] Validation ELBO loss: 158.2088, Likelihood loss: 13954.3037, KL divergence loss: 6296.4209
# Epoch [207 / 300] Training ELBO loss: 86.0447, Likelihood loss: 7439.3470, KL divergence loss: 3574.3710
# Epoch [207 / 300] Validation ELBO loss: 158.1016, Likelihood loss: 13997.7832, KL divergence loss: 6239.2158
# Epoch [208 / 300] Training ELBO loss: 86.1956, Likelihood loss: 7494.4063, KL divergence loss: 3538.6316
# Epoch [208 / 300] Validation ELBO loss: 158.4975, Likelihood loss: 14016.9600, KL divergence loss: 6270.7231
# Epoch [209 / 300] Training ELBO loss: 86.2033, Likelihood loss: 7427.7912, KL divergence loss: 3606.2311
# Epoch [209 / 300] Validation ELBO loss: 158.8072, Likelihood loss: 14018.6870, KL divergence loss: 6308.6409
# Epoch [210 / 300] Training ELBO loss: 85.2345, Likelihood loss: 7361.3199, KL divergence loss: 3548.6926
# Epoch [210 / 300] Validation ELBO loss: 157.9093, Likelihood loss: 14055.6772, KL divergence loss: 6156.7192
# Epoch [211 / 300] Training ELBO loss: 86.2868, Likelihood loss: 7525.3504, KL divergence loss: 3519.3659
# Epoch [211 / 300] Validation ELBO loss: 155.6078, Likelihood loss: 13613.2173, KL divergence loss: 6304.5850
# Epoch [212 / 300] Training ELBO loss: 85.5678, Likelihood loss: 7356.4818, KL divergence loss: 3596.1949
# Epoch [212 / 300] Validation ELBO loss: 157.2874, Likelihood loss: 13866.8472, KL divergence loss: 6265.9404
# Epoch [213 / 300] Training ELBO loss: 85.3212, Likelihood loss: 7367.8957, KL divergence loss: 3553.2171
# Epoch [213 / 300] Validation ELBO loss: 157.5134, Likelihood loss: 13951.3735, KL divergence loss: 6210.3457
# Epoch [214 / 300] Training ELBO loss: 85.5872, Likelihood loss: 7430.1634, KL divergence loss: 3524.9939
# Epoch [214 / 300] Validation ELBO loss: 155.6131, Likelihood loss: 13683.0459, KL divergence loss: 6235.4260
# Epoch [215 / 300] Training ELBO loss: 85.6583, Likelihood loss: 7439.1168, KL divergence loss: 3525.1446
# Epoch [215 / 300] Validation ELBO loss: 157.3281, Likelihood loss: 13952.3623, KL divergence loss: 6185.6345
# Epoch [216 / 300] Training ELBO loss: 85.0707, Likelihood loss: 7360.9463, KL divergence loss: 3528.1038
# Epoch [216 / 300] Validation ELBO loss: 156.6672, Likelihood loss: 13829.3359, KL divergence loss: 6224.0623
# Epoch [217 / 300] Training ELBO loss: 85.0680, Likelihood loss: 7352.0283, KL divergence loss: 3536.6745
# Epoch [217 / 300] Validation ELBO loss: 158.2179, Likelihood loss: 14062.9263, KL divergence loss: 6188.9617
# Epoch [218 / 300] Training ELBO loss: 85.4668, Likelihood loss: 7401.1703, KL divergence loss: 3538.5826
# Epoch [218 / 300] Validation ELBO loss: 156.5469, Likelihood loss: 13816.9082, KL divergence loss: 6221.1006
# Epoch [219 / 300] Training ELBO loss: 85.4150, Likelihood loss: 7400.1490, KL divergence loss: 3532.9696
# Epoch [219 / 300] Validation ELBO loss: 157.5625, Likelihood loss: 13961.7441, KL divergence loss: 6206.2590
# Epoch [220 / 300] Training ELBO loss: 84.6139, Likelihood loss: 7320.5786, KL divergence loss: 3509.9949
# Epoch [220 / 300] Validation ELBO loss: 154.4616, Likelihood loss: 13622.2783, KL divergence loss: 6148.8057
# Epoch [221 / 300] Training ELBO loss: 84.6639, Likelihood loss: 7343.5733, KL divergence loss: 3493.4038
# Epoch [221 / 300] Validation ELBO loss: 155.0230, Likelihood loss: 13673.3936, KL divergence loss: 6169.5459
# Epoch [222 / 300] Training ELBO loss: 84.1688, Likelihood loss: 7263.0158, KL divergence loss: 3510.5926
# Epoch [222 / 300] Validation ELBO loss: 155.8375, Likelihood loss: 13818.4399, KL divergence loss: 6128.7549
# Epoch [223 / 300] Training ELBO loss: 84.2399, Likelihood loss: 7301.3331, KL divergence loss: 3481.3789
# Epoch [223 / 300] Validation ELBO loss: 158.0704, Likelihood loss: 14055.1919, KL divergence loss: 6177.8174
# Epoch [224 / 300] Training ELBO loss: 84.8171, Likelihood loss: 7346.0414, KL divergence loss: 3510.5505
# Epoch [224 / 300] Validation ELBO loss: 156.5693, Likelihood loss: 13890.5518, KL divergence loss: 6150.3132
# ...
# Epoch [226 / 300] Validation ELBO loss: 155.9750, Likelihood loss: 13746.4512, KL divergence loss: 6218.3511
# Epoch [227 / 300] Training ELBO loss: 84.0350, Likelihood loss: 7230.1044, KL divergence loss: 3526.3695
# Epoch [227 / 300] Validation ELBO loss: 156.7461, Likelihood loss: 13910.6548, KL divergence loss: 6152.8481
# Epoch [228 / 300] Training ELBO loss: 84.2921, Likelihood loss: 7301.7996, KL divergence loss: 3487.5868
# Epoch [228 / 300] Validation ELBO loss: 154.8584, Likelihood loss: 13664.1284, KL divergence loss: 6157.7417
# Epoch [229 / 300] Training ELBO loss: 84.4818, Likelihood loss: 7279.7841, KL divergence loss: 3533.8862
# Epoch [229 / 300] Validation ELBO loss: 155.3165, Likelihood loss: 13752.7852, KL divergence loss: 6127.7239
# Epoch [230 / 300] Training ELBO loss: 84.2914, Likelihood loss: 7281.7754, KL divergence loss: 3507.5226
# Epoch [230 / 300] Validation ELBO loss: 154.6020, Likelihood loss: 13628.6426, KL divergence loss: 6160.4102
# Epoch [231 / 300] Training ELBO loss: 83.6953, Likelihood loss: 7199.0394, KL divergence loss: 3513.9594
# Epoch [231 / 300] Validation ELBO loss: 158.8291, Likelihood loss: 14175.2300, KL divergence loss: 6154.8892
# Epoch [232 / 300] Training ELBO loss: 84.6944, Likelihood loss: 7328.4428, KL divergence loss: 3512.4415
# Epoch [232 / 300] Validation ELBO loss: 155.5240, Likelihood loss: 13760.3315, KL divergence loss: 6146.7363
# Epoch [233 / 300] Training ELBO loss: 84.2775, Likelihood loss: 7265.2059, KL divergence loss: 3522.3100
# Epoch [233 / 300] Validation ELBO loss: 155.4022, Likelihood loss: 13678.7617, KL divergence loss: 6212.7231
# Epoch [234 / 300] Training ELBO loss: 82.9618, Likelihood loss: 7087.2769, KL divergence loss: 3531.8377
# Epoch [234 / 300] Validation ELBO loss: 154.8430, Likelihood loss: 13683.2827, KL divergence loss: 6136.6167
# Epoch [235 / 300] Training ELBO loss: 84.2433, Likelihood loss: 7279.7339, KL divergence loss: 3503.4025
# Epoch [235 / 300] Validation ELBO loss: 155.3115, Likelihood loss: 13691.4995, KL divergence loss: 6188.3728
# Epoch [236 / 300] Training ELBO loss: 83.6669, Likelihood loss: 7186.3628, KL divergence loss: 3522.9982
# Epoch [236 / 300] Validation ELBO loss: 155.9933, Likelihood loss: 13796.3037, KL divergence loss: 6170.8374
# Epoch [237 / 300] Training ELBO loss: 83.4705, Likelihood loss: 7187.7975, KL divergence loss: 3496.4237
# Epoch [237 / 300] Validation ELBO loss: 155.8638, Likelihood loss: 13891.4219, KL divergence loss: 6059.1506
# Epoch [238 / 300] Training ELBO loss: 83.8709, Likelihood loss: 7282.5686, KL divergence loss: 3452.9063
# Epoch [238 / 300] Validation ELBO loss: 153.1779, Likelihood loss: 13532.9570, KL divergence loss: 6073.8123
# Epoch [239 / 300] Training ELBO loss: 83.8108, Likelihood loss: 7223.7248, KL divergence loss: 3504.0608
# Epoch [239 / 300] Validation ELBO loss: 155.4471, Likelihood loss: 13708.8867, KL divergence loss: 6188.3452
# Epoch [240 / 300] Training ELBO loss: 83.8366, Likelihood loss: 7209.4338, KL divergence loss: 3521.6477
# Epoch [240 / 300] Validation ELBO loss: 153.8090, Likelihood loss: 13562.3101, KL divergence loss: 6125.2400
# Epoch [241 / 300] Training ELBO loss: 83.8381, Likelihood loss: 7227.7184, KL divergence loss: 3503.5559
# Epoch [241 / 300] Validation ELBO loss: 155.6570, Likelihood loss: 13765.4316, KL divergence loss: 6158.6667
# Epoch [242 / 300] Training ELBO loss: 83.7746, Likelihood loss: 7201.8626, KL divergence loss: 3521.2870
# Epoch [242 / 300] Validation ELBO loss: 155.6522, Likelihood loss: 13732.2549, KL divergence loss: 6191.2227
# Epoch [243 / 300] Training ELBO loss: 83.0589, Likelihood loss: 7130.2035, KL divergence loss: 3501.3321
# Epoch [243 / 300] Validation ELBO loss: 155.2454, Likelihood loss: 13791.3608, KL divergence loss: 6080.0510
# Epoch [244 / 300] Training ELBO loss: 83.1289, Likelihood loss: 7177.0411, KL divergence loss: 3463.4632
# Epoch [244 / 300] Validation ELBO loss: 154.1328, Likelihood loss: 13667.8979, KL divergence loss: 6061.1040
# Epoch [245 / 300] Training ELBO loss: 83.4337, Likelihood loss: 7189.3608, KL divergence loss: 3490.1504
# Epoch [245 / 300] Validation ELBO loss: 152.4807, Likelihood loss: 13384.2480, KL divergence loss: 6133.2869
# Epoch [246 / 300] Training ELBO loss: 83.4338, Likelihood loss: 7175.1040, KL divergence loss: 3504.4218
# Epoch [246 / 300] Validation ELBO loss: 154.2925, Likelihood loss: 13613.0938, KL divergence loss: 6136.3442
# Epoch [247 / 300] Training ELBO loss: 83.5262, Likelihood loss: 7207.2409, KL divergence loss: 3484.1121
# Epoch [247 / 300] Validation ELBO loss: 152.8944, Likelihood loss: 13474.1362, KL divergence loss: 6096.3508
# Epoch [248 / 300] Training ELBO loss: 83.1065, Likelihood loss: 7146.9112, KL divergence loss: 3490.7154
# Epoch [248 / 300] Validation ELBO loss: 155.0877, Likelihood loss: 13730.2583, KL divergence loss: 6120.9636
# Epoch [249 / 300] Training ELBO loss: 83.3584, Likelihood loss: 7157.6564, KL divergence loss: 3512.2178
# Epoch [249 / 300] Validation ELBO loss: 154.4435, Likelihood loss: 13576.9443, KL divergence loss: 6191.8208
# Epoch [250 / 300] Training ELBO loss: 83.0030, Likelihood loss: 7095.6335, KL divergence loss: 3528.7514
# Epoch [250 / 300] Validation ELBO loss: 154.1205, Likelihood loss: 13614.5073, KL divergence loss: 6112.9170
# Epoch [251 / 300] Training ELBO loss: 82.9328, Likelihood loss: 7141.2586, KL divergence loss: 3474.1394
# Epoch [251 / 300] Validation ELBO loss: 155.1012, Likelihood loss: 13777.1567, KL divergence loss: 6075.7961
# Epoch [252 / 300] Training ELBO loss: 82.1571, Likelihood loss: 7028.0542, KL divergence loss: 3488.0567
# Epoch [252 / 300] Validation ELBO loss: 153.8698, Likelihood loss: 13563.7197, KL divergence loss: 6131.6089
# Epoch [253 / 300] Training ELBO loss: 82.5932, Likelihood loss: 7095.4798, KL divergence loss: 3476.4482
# Epoch [253 / 300] Validation ELBO loss: 152.7571, Likelihood loss: 13461.1597, KL divergence loss: 6091.7534
# Epoch [254 / 300] Training ELBO loss: 82.7927, Likelihood loss: 7125.2948, KL divergence loss: 3472.1745
# Epoch [254 / 300] Validation ELBO loss: 152.7071, Likelihood loss: 13469.8921, KL divergence loss: 6076.6187
# Epoch [255 / 300] Training ELBO loss: 82.9791, Likelihood loss: 7102.5639, KL divergence loss: 3518.7577
# Epoch [255 / 300] Validation ELBO loss: 155.3356, Likelihood loss: 13746.3789, KL divergence loss: 6136.5806
# Epoch [256 / 300] Training ELBO loss: 82.7924, Likelihood loss: 7087.6736, KL divergence loss: 3509.7595
# Epoch [256 / 300] Validation ELBO loss: 154.6816, Likelihood loss: 13659.1260, KL divergence loss: 6140.1228
# Epoch [257 / 300] Training ELBO loss: 82.4769, Likelihood loss: 7061.4846, KL divergence loss: 3495.5546
# Epoch [257 / 300] Validation ELBO loss: 153.7596, Likelihood loss: 13617.6221, KL divergence loss: 6063.6123
# Epoch [258 / 300] Training ELBO loss: 82.7613, Likelihood loss: 7124.5866, KL divergence loss: 3468.8633
# Epoch [258 / 300] Validation ELBO loss: 151.7364, Likelihood loss: 13322.9473, KL divergence loss: 6099.3125
# Epoch [259 / 300] Training ELBO loss: 82.4753, Likelihood loss: 7057.6464, KL divergence loss: 3499.1903
# Epoch [259 / 300] Validation ELBO loss: 154.3543, Likelihood loss: 13603.2373, KL divergence loss: 6154.1194
# Epoch [260 / 300] Training ELBO loss: 82.1653, Likelihood loss: 7016.8518, KL divergence loss: 3500.3079
# Epoch [260 / 300] Validation ELBO loss: 152.9687, Likelihood loss: 13480.4360, KL divergence loss: 6099.5632
# Epoch [261 / 300] Training ELBO loss: 81.8048, Likelihood loss: 6981.1102, KL divergence loss: 3489.9009
# Epoch [261 / 300] Validation ELBO loss: 153.4796, Likelihood loss: 13569.7104, KL divergence loss: 6075.6833
# Epoch [262 / 300] Training ELBO loss: 82.2168, Likelihood loss: 7032.9881, KL divergence loss: 3490.7657
# Epoch [262 / 300] Validation ELBO loss: 151.8718, Likelihood loss: 13323.8638, KL divergence loss: 6115.7314
# Epoch [263 / 300] Training ELBO loss: 81.8996, Likelihood loss: 7013.0881, KL divergence loss: 3470.0653
# Epoch [263 / 300] Validation ELBO loss: 153.8621, Likelihood loss: 13699.9648, KL divergence loss: 5994.3877
# Epoch [264 / 300] Training ELBO loss: 82.6771, Likelihood loss: 7127.1632, KL divergence loss: 3455.5071
# Epoch [264 / 300] Validation ELBO loss: 153.7756, Likelihood loss: 13558.2510, KL divergence loss: 6125.0234
# Epoch [265 / 300] Training ELBO loss: 81.6874, Likelihood loss: 6956.0681, KL divergence loss: 3499.9199
# Epoch [265 / 300] Validation ELBO loss: 153.4180, Likelihood loss: 13579.1504, KL divergence loss: 6058.3481
# Epoch [266 / 300] Training ELBO loss: 82.0995, Likelihood loss: 7043.8036, KL divergence loss: 3464.9348
# Epoch [266 / 300] Validation ELBO loss: 152.6021, Likelihood loss: 13417.3789, KL divergence loss: 6115.6943
# Epoch [267 / 300] Training ELBO loss: 81.7797, Likelihood loss: 6982.1720, KL divergence loss: 3485.6323
# Epoch [267 / 300] Validation ELBO loss: 151.3404, Likelihood loss: 13315.6738, KL divergence loss: 6055.8933
# Epoch [268 / 300] Training ELBO loss: 81.6872, Likelihood loss: 6996.5365, KL divergence loss: 3459.4212
# Epoch [268 / 300] Validation ELBO loss: 150.6893, Likelihood loss: 13268.9478, KL divergence loss: 6019.2773
# Epoch [269 / 300] Training ELBO loss: 81.4928, Likelihood loss: 6983.6727, KL divergence loss: 3447.4115
# Epoch [269 / 300] Validation ELBO loss: 154.3812, Likelihood loss: 13718.3359, KL divergence loss: 6042.4575
# Epoch [270 / 300] Training ELBO loss: 81.4550, Likelihood loss: 6946.0635, KL divergence loss: 3480.1736
# Epoch [270 / 300] Validation ELBO loss: 151.7561, Likelihood loss: 13377.9937, KL divergence loss: 6046.7844
# Epoch [271 / 300] Training ELBO loss: 81.9845, Likelihood loss: 7006.0511, KL divergence loss: 3487.9607
# Epoch [271 / 300] Validation ELBO loss: 152.0937, Likelihood loss: 13343.3452, KL divergence loss: 6124.6533
# Epoch [272 / 300] Training ELBO loss: 81.5020, Likelihood loss: 6914.6381, KL divergence loss: 3517.6222
# Epoch [272 / 300] Validation ELBO loss: 152.8622, Likelihood loss: 13480.3730, KL divergence loss: 6085.9822
# Epoch [273 / 300] Training ELBO loss: 81.7219, Likelihood loss: 6974.2658, KL divergence loss: 3486.1429
# Epoch [273 / 300] Validation ELBO loss: 151.8912, Likelihood loss: 13405.2217, KL divergence loss: 6036.8479
# Epoch [274 / 300] Training ELBO loss: 80.9124, Likelihood loss: 6931.3528, KL divergence loss: 3425.4387
# Epoch [274 / 300] Validation ELBO loss: 150.6004, Likelihood loss: 13310.8970, KL divergence loss: 5965.9565
# Epoch [275 / 300] Training ELBO loss: 81.3463, Likelihood loss: 6973.3249, KL divergence loss: 3438.9980
# Epoch [275 / 300] Validation ELBO loss: 151.5979, Likelihood loss: 13318.2983, KL divergence loss: 6086.2275
# Epoch [276 / 300] Training ELBO loss: 81.7657, Likelihood loss: 6979.0311, KL divergence loss: 3486.9735
# Epoch [276 / 300] Validation ELBO loss: 154.1695, Likelihood loss: 13659.5938, KL divergence loss: 6074.1050
# Epoch [277 / 300] Training ELBO loss: 81.5360, Likelihood loss: 6990.0756, KL divergence loss: 3446.5305
# Epoch [277 / 300] Validation ELBO loss: 151.2082, Likelihood loss: 13372.4785, KL divergence loss: 5982.1707
# Epoch [278 / 300] Training ELBO loss: 80.7847, Likelihood loss: 6880.7343, KL divergence loss: 3459.7120
# Epoch [278 / 300] Validation ELBO loss: 152.4360, Likelihood loss: 13454.9277, KL divergence loss: 6056.8752
# Epoch [279 / 300] Training ELBO loss: 81.2169, Likelihood loss: 6953.8586, KL divergence loss: 3441.9036
# Epoch [279 / 300] Validation ELBO loss: 152.3252, Likelihood loss: 13545.1045, KL divergence loss: 5952.5239
# Epoch [280 / 300] Training ELBO loss: 80.5648, Likelihood loss: 6866.8957, KL divergence loss: 3445.4035
# Epoch [280 / 300] Validation ELBO loss: 152.0808, Likelihood loss: 13435.0698, KL divergence loss: 6031.2698
# Epoch [281 / 300] Training ELBO loss: 80.9571, Likelihood loss: 6939.4059, KL divergence loss: 3423.0986
# Epoch [281 / 300] Validation ELBO loss: 149.6685, Likelihood loss: 13250.7363, KL divergence loss: 5906.8276
# Epoch [282 / 300] Training ELBO loss: 81.1824, Likelihood loss: 6992.4949, KL divergence loss: 3398.8526
# Epoch [282 / 300] Validation ELBO loss: 151.4447, Likelihood loss: 13369.5923, KL divergence loss: 6015.3335
# Epoch [283 / 300] Training ELBO loss: 80.7351, Likelihood loss: 6894.1182, KL divergence loss: 3439.9783
# Epoch [283 / 300] Validation ELBO loss: 151.9356, Likelihood loss: 13380.8599, KL divergence loss: 6066.8928
# Epoch [284 / 300] Training ELBO loss: 80.7192, Likelihood loss: 6860.1596, KL divergence loss: 3471.8976
# Epoch [284 / 300] Validation ELBO loss: 150.3101, Likelihood loss: 13189.2827, KL divergence loss: 6050.4053
# Epoch [285 / 300] Training ELBO loss: 80.2344, Likelihood loss: 6829.8078, KL divergence loss: 3440.1964
# Epoch [285 / 300] Validation ELBO loss: 151.0406, Likelihood loss: 13379.9150, KL divergence loss: 5953.2793
# Epoch [286 / 300] Training ELBO loss: 80.6292, Likelihood loss: 6885.0011, KL divergence loss: 3435.5381
# Epoch [286 / 300] Validation ELBO loss: 152.3520, Likelihood loss: 13481.1299, KL divergence loss: 6019.9294
# Epoch [287 / 300] Training ELBO loss: 80.8065, Likelihood loss: 6879.7272, KL divergence loss: 3463.5095
# Epoch [287 / 300] Validation ELBO loss: 150.2322, Likelihood loss: 13167.9956, KL divergence loss: 6061.7307
# Epoch [288 / 300] Training ELBO loss: 80.6562, Likelihood loss: 6887.4452, KL divergence loss: 3436.5444
# Epoch [288 / 300] Validation ELBO loss: 153.8794, Likelihood loss: 13728.9287, KL divergence loss: 5967.6321
# Epoch [289 / 300] Training ELBO loss: 80.1676, Likelihood loss: 6834.7258, KL divergence loss: 3426.7231
# Epoch [289 / 300] Validation ELBO loss: 152.7001, Likelihood loss: 13585.7173, KL divergence loss: 5959.8975
# Epoch [290 / 300] Training ELBO loss: 80.5167, Likelihood loss: 6894.7410, KL divergence loss: 3411.3922
# Epoch [290 / 300] Validation ELBO loss: 148.6459, Likelihood loss: 13053.8701, KL divergence loss: 5972.8093
# Epoch [291 / 300] Training ELBO loss: 80.3406, Likelihood loss: 6824.4294, KL divergence loss: 3459.1736
# Epoch [291 / 300] Validation ELBO loss: 149.2764, Likelihood loss: 13079.0234, KL divergence loss: 6028.3523
# Epoch [292 / 300] Training ELBO loss: 80.3232, Likelihood loss: 6859.4808, KL divergence loss: 3421.8915
# Epoch [292 / 300] Validation ELBO loss: 150.3164, Likelihood loss: 13294.7251, KL divergence loss: 5945.7754
# Epoch [293 / 300] Training ELBO loss: 80.9201, Likelihood loss: 6899.2794, KL divergence loss: 3458.4988
# Epoch [293 / 300] Validation ELBO loss: 151.6988, Likelihood loss: 13284.2627, KL divergence loss: 6133.1821
# Epoch [294 / 300] Training ELBO loss: 80.8664, Likelihood loss: 6805.9833, KL divergence loss: 3544.9220
# Epoch [294 / 300] Validation ELBO loss: 151.4467, Likelihood loss: 13270.6270, KL divergence loss: 6114.5479
# Epoch [295 / 300] Training ELBO loss: 79.8623, Likelihood loss: 6753.4134, KL divergence loss: 3468.9567
# Epoch [295 / 300] Validation ELBO loss: 151.1282, Likelihood loss: 13409.8730, KL divergence loss: 5934.5361
# Epoch [296 / 300] Training ELBO loss: 80.1915, Likelihood loss: 6844.5614, KL divergence loss: 3419.9529
# Epoch [296 / 300] Validation ELBO loss: 152.3675, Likelihood loss: 13491.9121, KL divergence loss: 6011.1265
# Epoch [297 / 300] Training ELBO loss: 79.8575, Likelihood loss: 6772.7222, KL divergence loss: 3449.0386
# Epoch [297 / 300] Validation ELBO loss: 150.9826, Likelihood loss: 13354.6191, KL divergence loss: 5971.1487
# Epoch [298 / 300] Training ELBO loss: 80.4022, Likelihood loss: 6893.0829, KL divergence loss: 3398.4049
# Epoch [298 / 300] Validation ELBO loss: 150.0988, Likelihood loss: 13228.7471, KL divergence loss: 5983.9016
# Epoch [299 / 300] Training ELBO loss: 80.0862, Likelihood loss: 6810.7833, KL divergence loss: 3440.2449
# Epoch [299 / 300] Validation ELBO loss: 149.2251, Likelihood loss: 13126.2617, KL divergence loss: 5974.5461
# Epoch [300 / 300] Training ELBO loss: 79.7742, Likelihood loss: 6801.5022, KL divergence loss: 3409.5892
# Epoch [300 / 300] Validation ELBO loss: 149.7982, Likelihood loss: 13193.5068, KL divergence loss: 5980.6584
# --- TOTAL TIME: 16.203 min ---

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
# fig.tight_layout()

loss_types = ["elbo", "likelihood", "kl_div"]
y_labels = ["ELBO Loss", "Likelihood Loss", "KL Divergence Loss"]

for i, loss_type in enumerate(loss_types):
    (train_h,) = axs[i].plot(train_loss_avg[loss_type], label="Train")
    (val_h,) = axs[i].plot(val_loss_avg[loss_type], label="Validation")
    axs[i].set_xlabel("Epochs")
    axs[i].set_title(y_labels[i])
    axs[i].grid(True)

fig.legend(handles=[train_h, val_h], loc="upper center", bbox_to_anchor=(0.5, 1.15))
plt.show()

# %%
plt.figure(figsize=(8, 6))

train_elbo, = plt.plot(train_loss_avg['elbo'], label="Train ELBO Loss")
val_elbo, = plt.plot(val_loss_avg['elbo'], label="Validation ELBO Loss")

plt.xlabel("Epochs")
plt.ylabel("ELBO Loss")
plt.grid(True)
plt.legend()
plt.show()

# %%
# this is how the VAE parameters can be saved:
torch.save(vae.state_dict(), '/content/drive/MyDrive/TFM/my_vae_ft_2.pth')

# %%
# Load checkpoint
checkpoint=torch.load('/content/drive/MyDrive/TFM/my_vae_ft_2.pth', map_location=torch.device('cpu'))

vae = VariationalAutoencoder(z_dims = hparams['latent_dims'], n_ch = hparams['channels'])
vae.load_state_dict(checkpoint)
print('model loaded')
# Out:
# model loaded

# %% [markdown]
# ### Evaluate on the Test Set

# %%
# Set to evaluation mode
vae.eval()

latent_mu_list = []
latent_logvar_list = []
class_labels_64_list = []
class_labels_2_list = []

all_participants_count = {}

with torch.no_grad():
    test_loss_avg = {"elbo": 0, "likelihood": 0, "kl_div": 0}
    num_test_batches = 0

    for x_test_batch, file_names in test_dataloader:
        x_test_batch = x_test_batch
        # VAE reconstruction
        x_test_batch_recon, latent_mu_test, latent_logvar_test = vae(
            x_test_batch
        )

        # Calculate reconstruction error and other losses
        test_loss, likelihood, kl_div = vae_loss(
            x_test_batch_recon,
            x_test_batch,
            latent_mu_test,
            latent_logvar_test,
        )

        test_loss_avg["elbo"] += test_loss.item()
        test_loss_avg["likelihood"] += likelihood.item()
        test_loss_avg["kl_div"] += kl_div.item()
        num_test_batches += 1

        latent_mu_list.append(latent_mu_test.cpu().numpy())
        latent_logvar_list.append(latent_logvar_test.cpu().numpy())

        class_labels_64_list.extend([file_name.split('_')[1] for file_name in file_names])
        class_labels_2_list.extend([file_name.split('_')[1][0] for file_name in file_names])

        # Update participant counts in the test set
        for file_name in file_names:
            participant_code = file_name.split('_')[1]
            if participant_code not in all_participants_count:
                all_participants_count[participant_code] = 1
            else:
                all_participants_count[participant_code] += 1

    # Calculate average losses
    test_loss_avg["elbo"] /= num_test_batches
    test_loss_avg["likelihood"] /= num_test_batches
    test_loss_avg["kl_div"] /= num_test_batches

# Print and save the test losses
print("Average ELBO loss on test data: %f" % test_loss_avg["elbo"])
print("Average Likelihood loss on test data: %f" % test_loss_avg["likelihood"])
print("Average KL Divergence loss on test data: %f" % test_loss_avg["kl_div"])

# Combine all latent_mu and latent_logvar into single matrices
latent_mu_test = np.concatenate(latent_mu_list, axis=0)
latent_logvar_test = np.concatenate(latent_logvar_list, axis=0)

# Combine mu and logvar into one matrix & extract class labels
latent_matrix = np.concatenate((latent_mu_test, latent_logvar_test), axis=1)
class_labels_64 = np.array(class_labels_64_list)
class_labels_2 = np.array(class_labels_2_list)
# Out:
# Average ELBO loss on test data: 80.268829
# Average Likelihood loss on test data: 10848.572266
# Average KL Divergence loss on test data: 4563.043457

# %%
# # Set to evaluation mode
# vae.eval()

# latent_mu_list = []
# latent_logvar_list = []
# class_labels_30_list = []

# all_participants_count = {}

# with torch.no_grad():
#     for x_test_batch, file_names in participant_dataloader:

#         # VAE reconstruction
#         x_test_batch_recon, latent_mu_test, latent_logvar_test = vae(
#             x_test_batch
#         )

#         # Calculate reconstruction error and other losses
#         test_loss, likelihood, kl_div = vae_loss(
#             x_test_batch_recon,
#             x_test_batch,
#             latent_mu_test,
#             latent_logvar_test,
#         )

#         latent_mu_list.append(latent_mu_test.cpu().numpy())
#         latent_logvar_list.append(latent_logvar_test.cpu().numpy())

#         class_labels_30_list.extend([file_name.split('_')[5] for file_name in file_names])

#         # Update participant counts in the test set
#         for file_name in file_names:
#             participant_code = file_name.split('_')[1]
#             if participant_code not in all_participants_count:
#                 all_participants_count[participant_code] = 1
#             else:
#                 all_participants_count[participant_code] += 1

# # Combine all latent_mu and latent_logvar into single matrices
# latent_mu_test = np.concatenate(latent_mu_list, axis=0)
# latent_logvar_test = np.concatenate(latent_logvar_list, axis=0)

# # Combine mu and logvar into one matrix & extract class labels
# latent_matrix = np.concatenate((latent_mu_test, latent_logvar_test), axis=1)
# class_labels_30 = np.array(class_labels_30_list)

# %%
# 'all_participants_count' dictionary now contains counts of each participant in the test set
print("Participants and their counts in the test set:")
for participant, count in all_participants_count.items():
    print(f"Participant {participant}: {count} occurrences")
# Out:
# Participants and their counts in the test set:
# Participant A09: 3 occurrences
# Participant A31: 3 occurrences
# Participant A13: 5 occurrences
# Participant A05: 5 occurrences
# Participant P26: 2 occurrences
# Participant P18: 2 occurrences
# Participant P07: 3 occurrences
# Participant A02: 5 occurrences
# Participant A23: 4 occurrences
# Participant P24: 4 occurrences
# Participant A08: 2 occurrences
# Participant P08: 4 occurrences
# Participant A27: 3 occurrences
# Participant P14: 4 occurrences
# Participant P31: 4 occurrences
# Participant P28: 4 occurrences
# Participant A01: 6 occurrences
# Participant P21: 3 occurrences
# Participant P11: 4 occurrences
# Participant P01: 3 occurrences
# Participant P20: 2 occurrences
# Participant P06: 2 occurrences
# Participant P30: 2 occurrences
# Participant P32: 3 occurrences
# Participant P19: 3 occurrences
# Participant A06: 3 occurrences
# Participant P03: 3 occurrences
# Participant A29: 3 occurrences
# Participant A15: 2 occurrences
# Participant A22: 4 occurrences
# Participant P02: 4 occurrences
# Participant A28: 3 occurrences
# Participant P29: 3 occurrences
# Participant P15: 4 occurrences
# Participant A18: 5 occurrences
# Participant A25: 3 occurrences
# Participant A12: 4 occurrences
# Participant A30: 2 occurrences
# Participant A03: 1 occurrences
# Participant A19: 3 occurrences
# Participant A07: 3 occurrences
# Participant P10: 2 occurrences
# Participant A17: 2 occurrences
# Participant P16: 7 occurrences
# Participant A04: 4 occurrences
# Participant A11: 2 occurrences
# Participant P23: 5 occurrences
# Participant P12: 2 occurrences
# Participant A14: 4 occurrences
# Participant A10: 3 occurrences
# Participant P27: 2 occurrences
# Participant P17: 4 occurrences
# Participant P22: 2 occurrences
# Participant P09: 2 occurrences
# Participant A21: 2 occurrences
# Participant P34: 4 occurrences
# Participant P13: 1 occurrences
# Participant P33: 3 occurrences
# Participant P04: 2 occurrences
# Participant A20: 3 occurrences
# Participant A24: 1 occurrences

# %% [markdown]
# **Visualize Generated Images**

# %%
# This function takes as an input the images to reconstruct
# and the name of the model with which the reconstructions
# are performed
def to_img(x: torch.Tensor) -> torch.Tensor:
    x = x.clamp(0, 1)
    return x

def show_image(img: torch.Tensor) -> None:
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)), cmap='gray')

def one_hot_encode(image: torch.Tensor) -> torch.Tensor:
    max_indices = torch.argmax(image, dim=1, keepdim=True)
    binary_image = torch.zeros_like(image)
    binary_image.scatter_(1, max_indices, 1)
    return image
    #return binary_image

@torch.no_grad()
def visualise_output(images: torch.Tensor, model: nn.Module, device: torch.device) -> None:
    images = images.to(device)
    model.to(device)
    recon_images, _, _ = model(images)
    recon_images = recon_images.cpu()

    # Plot each original-reconstructed pair separately
    for i in range(images.size(0)):
        plt.figure(figsize=(10, 5))

        plt.subplot(1, 2, 1)
        plt.title('Original Image')
        show_image(one_hot_encode(images[i].cpu()))

        plt.subplot(1, 2, 2)
        plt.title('Reconstructed Image')
        show_image(one_hot_encode(recon_images[i]))

        plt.show()

# %%
vae.eval()
test_data_iterator = iter(test_dataloader)
images, labels = next(test_data_iterator)

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images[1:10], vae, device)
# Out:
# VAE reconstruction:

# %% [markdown]
# **Analyze Latent Space**

# %%
# Assuming latent_matrix is the concatenated matrix

print("Shape of Latent Matrix:", latent_matrix.shape)
# 192 samples in test set (rows)
# 70*2 latent dimension = features (columns)

# Visualizing a heatmap of the matrix
plt.figure(figsize=(8, 6))
sns.heatmap(latent_matrix[:100], cmap='viridis')  # Displaying the first 100 rows as a heatmap
plt.title('Latent Matrix Heatmap (Sample)')
plt.xlabel('Latent Dimensions')
plt.ylabel('Sample Index')
plt.show()
# Out:
# Shape of Latent Matrix: (192, 140)

# %%
# Perform Singular Value Decomposition (SVD)
U, s, V = np.linalg.svd(latent_matrix, full_matrices=False)

# %%
SignValue = s
plt.plot(SignValue,'.-');
plt.title(f'Plot of the value of the singular values of latent matrix')
plt.ylabel('Singular Value')
plt.xlabel('Order of the Singular Value')
plt.grid(True)
plt.show()

plt.plot(np.cumsum(SignValue)/np.sum(SignValue)*100,'.-');
plt.title(f'Cummulative plot of the value of the Singular Values of latent matrix')
plt.ylabel('Cummulative Value (%)')
plt.xlabel('Order of the Singular Value')
plt.grid(True)
plt.show()

# %%
num_components = hparams['latent_dims']

# %%
# Filter the latent matrix and class labels for class 'A'
class_A_indices = np.where(class_labels_2 == 'A')[0]
latent_matrix_class_A = latent_matrix[class_A_indices]
class_labels_64_class_A = class_labels_64[class_A_indices]

# Filter the latent matrix and class labels for class 'P'
class_P_indices = np.where(class_labels_2 == 'P')[0]
latent_matrix_class_P = latent_matrix[class_P_indices]
class_labels_64_class_P = class_labels_64[class_P_indices]

# %%
# Perform Principal Component Analysis (PCA)

#pca = PCA(n_components='mle')
pca = PCA(n_components=num_components)
#pca = PCA(n_components=30)
#pca = PCA(n_components=len(class_A_indices))
pca_result = pca.fit_transform(latent_matrix_class_A)
print(pca.n_components_)
# Out:
# 70

# %%
# Obtain the explained variance ratios and cumulative explained variance
explained_variance_ratios = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratios)

# Plotting the scree plot
#plt.figure(figsize=(8, 6))
plt.plot(range(1, len(explained_variance_ratios) + 1), explained_variance_ratios, '.-')
plt.title('Scree Plot for Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

# Plotting cumulative explained variance
#plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, '.-')
plt.title('Cumulative Explained Variance Ratio by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
# Convert class labels to numeric values
label_df = pd.DataFrame(class_labels_64_class_P, columns=['Class'])
label_df['ClassID'] = label_df['Class'].astype('category').cat.codes  # Convert labels to numeric IDs

# Get unique classes from the data
unique_classes = label_df['Class'].unique()

# Create a colormap for the classes
colormap = plt.cm.get_cmap('plasma', len(unique_classes))
# Out:
# <ipython-input-53-e45fd7ce9f2a>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = plt.cm.get_cmap('plasma', len(unique_classes))

# %%
colors = {'A': 'mediumturquoise', 'P': 'darkorange'}

for class_label, color in colors.items():
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        pca_result[class_indices, 0],
        pca_result[class_indices, 1],
        label=class_label,
        color=color,
        alpha=0.5
    )

plt.title('PCA Visualization of Latent Space (4-bar)')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend()
plt.show()

# %%
# Combine the components in a DataFrame for visualization
n_comps = 10
pca_df = pd.DataFrame(data=pca_result[:, :n_comps], columns=[f'Component {i+1}' for i in range(n_comps)])

# Add class labels to the DataFrame
pca_df['Class'] = label_df['Class']

# Create a scatter matrix
scatter_matrix = sns.pairplot(pca_df, hue='Class', palette='plasma')

# Access the current figure and axes to plot the legend separately
fig = plt.gcf()
handles = list(scatter_matrix._legend_data.values())[:1]
labels = list(scatter_matrix._legend_data.keys())[:1]
fig.legend(handles, labels, loc='center right')

plt.suptitle('Pairwise Scatter Matrix of Principal Components', fontsize=20, position=(0.5, 1))
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Create a scatter plot with annotations for trial numbers
for i, class_label in enumerate(unique_classes):
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        pca_result[class_indices, 0],
        pca_result[class_indices, 1],
        label=f'Trial {class_label}',  # Label each point with its trial number
        cmap=colormap,
        alpha=0.5
    )
    # Annotate each point with its trial number
    for idx in class_indices:
        plt.annotate(str(class_label), (pca_result[idx, 0], pca_result[idx, 1]))

plt.title('PCA Visualization of Latent Space of A01')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# <ipython-input-33-ef144bcdc5b0>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
# Create a scatter plot with annotations for trial numbers
for i, class_label in enumerate(unique_classes):
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        pca_result[class_indices, 0],
        pca_result[class_indices, 1],
        label=f'Trial {class_label}',  # Label each point with its trial number
        cmap=colormap,
        alpha=0.5
    )
    # Annotate each point with its trial number
    for idx in class_indices:
        plt.annotate(str(class_label), (pca_result[idx, 0], pca_result[idx, 1]))

plt.title('PCA Visualization of Latent Space of A03')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# <ipython-input-34-cb8d7c21b013>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
# Create a scatter plot with annotations for trial numbers
for i, class_label in enumerate(unique_classes):
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        pca_result[class_indices, 0],
        pca_result[class_indices, 1],
        label=f'Trial {class_label}',  # Label each point with its trial number
        cmap=colormap,
        alpha=0.5
    )
    # Annotate each point with its trial number
    for idx in class_indices:
        plt.annotate(str(class_label), (pca_result[idx, 0], pca_result[idx, 1]))

plt.title('PCA Visualization of Latent Space of P01')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# <ipython-input-35-7fbfcb197f14>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
# Create a scatter plot with annotations for trial numbers
for i, class_label in enumerate(unique_classes):
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        pca_result[class_indices, 0],
        pca_result[class_indices, 1],
        label=f'Trial {class_label}',  # Label each point with its trial number
        cmap=colormap,
        alpha=0.5
    )
    # Annotate each point with its trial number
    for idx in class_indices:
        plt.annotate(str(class_label), (pca_result[idx, 0], pca_result[idx, 1]))

plt.title('PCA Visualization of Latent Space of P03')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# <ipython-input-36-86a462bf0bb0>:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
pca_result_P = pca.transform(latent_matrix_class_P)

# Scatter plot for class 'P'
plt.scatter(
    pca_result_P[:, 0],
    pca_result_P[:, 1],
    label='P',
    color='darkorange',
    alpha=0.5
)

# Scatter plot for class 'A'
plt.scatter(
    pca_result[:, 0],
    pca_result[:, 1],
    label='A',
    color='mediumturquoise',
    alpha=0.5
)

plt.title('PCA Visualization of Latent Space of A with P samples (4-bar)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# %% [markdown]
# **Visualize Latent Space**

# %%
# t-SNE
tsne = TSNE(n_components=3, random_state=42)
latent_tsne = tsne.fit_transform(latent_matrix)
print(latent_tsne.shape)
# Out:
# (192, 3)

# %%
colors = {'A': 'mediumturquoise', 'P': 'darkorange'}

for class_label, color in colors.items():
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        latent_tsne[class_indices, 0],
        latent_tsne[class_indices, 1],
        label=class_label,
        color=color,
        alpha=0.5
    )

plt.title('t-SNE Visualization of Latent Space (4-bar)')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend()
plt.show()

# %%
# Combine the components in a DataFrame for visualization
tsne_df = pd.DataFrame(data=latent_tsne[:, :3], columns=[f'Component {i+1}' for i in range(3)])

# Add class labels to the DataFrame
tsne_df['Class'] = label_df['Class']

# Create a scatter matrix
scatter_matrix = sns.pairplot(tsne_df, hue='Class', palette='plasma')

# Access the current figure and axes to plot the legend separately
fig = plt.gcf()
handles = list(scatter_matrix._legend_data.values())[:1]
labels = list(scatter_matrix._legend_data.keys())[:1]
fig.legend(handles, labels, loc='center right')

plt.suptitle('Pairwise Scatter Matrix of Principal Components', fontsize=20, position=(0.5, 1))
plt.show()

# %%
# MDS
mds = MDS(n_components=num_components, random_state=42)
latent_mds = mds.fit_transform(latent_matrix)
print(latent_mds.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# (192, 70)

# %%
colors = {'A': 'mediumturquoise', 'P': 'darkorange'}

for class_label, color in colors.items():
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        latent_mds[class_indices, 0],
        latent_mds[class_indices, 1],
        label=class_label,
        color=color,
        alpha=0.5
    )

plt.title('MDS Visualization of Latent Space (4-bar)')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend()
plt.show()

# %%
# Combine the components in a DataFrame for visualization
mds_df = pd.DataFrame(data=latent_mds[:, :10], columns=[f'Component {i+1}' for i in range(10)])

# Add class labels to the DataFrame
mds_df['Class'] = label_df['Class']

# Create a scatter matrix
scatter_matrix = sns.pairplot(mds_df, hue='Class', palette='plasma')

# Access the current figure and axes to plot the legend separately
fig = plt.gcf()
handles = list(scatter_matrix._legend_data.values())[:1]
labels = list(scatter_matrix._legend_data.keys())[:1]
fig.legend(handles, labels, loc='center right')

plt.suptitle('Pairwise Scatter Matrix of Principal Components', fontsize=20, position=(0.5, 1))
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# UMAP
umap_emb = umap.UMAP(n_components=num_components, random_state=42)
latent_umap = umap_emb.fit_transform(latent_matrix)
print(latent_umap.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# (192, 70)

# %%
colors = {'A': 'mediumturquoise', 'P': 'darkorange'}

for class_label, color in colors.items():
    class_indices = label_df[label_df['Class'] == class_label].index
    plt.scatter(
        latent_umap[class_indices, 0],
        latent_umap[class_indices, 1],
        label=class_label,
        color=color,
        alpha=0.5
    )

plt.title('UMAP Visualization of Latent Space (4-bar)')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend()
plt.show()

# %%
# Combine the components in a DataFrame for visualization
umap_df = pd.DataFrame(data=latent_umap[:, :10], columns=[f'Component {i+1}' for i in range(10)])

# Add class labels to the DataFrame
umap_df['Class'] = label_df['Class']

# Create a scatter matrix
scatter_matrix = sns.pairplot(umap_df, hue='Class', palette='plasma')

# Access the current figure and axes to plot the legend separately
fig = plt.gcf()
handles = list(scatter_matrix._legend_data.values())[:1]
labels = list(scatter_matrix._legend_data.keys())[:1]
fig.legend(handles, labels, loc='center right')

plt.suptitle('Pairwise Scatter Matrix of Principal Components', fontsize=20, position=(0.5, 1))
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
