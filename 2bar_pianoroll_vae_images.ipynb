# %%
import os
import time

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torchvision.utils
import torch.nn.functional as F
import torchvision.transforms as transforms

from typing import Tuple
from torchvision import datasets
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, MDS
# !pip install umap-learn
import umap

from PIL import Image

import seaborn as sns
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)

# %%
seed = 123
np.random.seed(seed)
_ = torch.manual_seed(seed)
_ = torch.cuda.manual_seed(seed)

# %%
# we select to work on GPU if it is available in the machine, otherwise will run on CPU
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Defining the Hyper-parameters**

# %%
hparams = {
    'batch_size':128,
    'num_epochs':100,
    'channels':64,
    'latent_dims':40,
    'variational_beta':1,
    'learning_rate':1e-3,
    'weight_decay':1e-5,
    'dropout_prob':0.2
}

# %% [markdown]
# **Defining the Pytorch Dataset and the DataLoader**

# %%
# Define a custom transformation function
def custom_transform(piano_roll_data):
    # Convert the binary piano roll data to a NumPy array
    piano_roll_array = np.array(piano_roll_data, dtype=np.float32)

    # Convert the NumPy array to a PIL Image
    piano_roll_image = Image.fromarray(piano_roll_array)

    # Apply any additional transformations if needed
    transform = transforms.Compose([
        transforms.Resize((25, 36)),
        transforms.ToTensor(),
    ])
    piano_roll_image = transform(piano_roll_image)

    return piano_roll_image

# %%
class PianoRollImageDataset(Dataset):
    def __init__(self, data_folder, file_list, transform=None):
        self.data_folder = data_folder
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        file_path = os.path.join(self.data_folder, file_name)

        piano_roll_data = []
        # Read the piano roll data from the text file
        with open(file_path, "r") as file:
            for i, line in enumerate(file):
                piano_roll_data.append([int(val) for val in line.split()])

        # Check the dimensions
        vertical_dimension = len(piano_roll_data)
        horizontal_dimension = len(piano_roll_data[0])

        # Convert to a PyTorch tensor using the custom transformation
        piano_roll_image = custom_transform(piano_roll_data)

        return piano_roll_image, file_name

# %%
# Define the data folder
data_folder = '/content/drive/MyDrive/UNI/2_bar_text_dataset'
#data_folder = '/content/drive/MyDrive/TFM/2_bar_text_dataset'

# Split the dataset into training, validation, and test sets
file_list = os.listdir(data_folder)
print(len(file_list))
train_files, val_files = train_test_split(file_list, test_size=0.3, random_state=42)
val_files, test_files = train_test_split(val_files, test_size=0.333, random_state=42)

# Dataset initialization
train_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=train_files)
val_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=val_files)
test_dataset = PianoRollImageDataset(data_folder, transform=custom_transform, file_list=test_files)

# Dataloaders initialization
train_dataloader = torch.utils.data.DataLoader(
    dataset=train_dataset,
    batch_size=hparams['batch_size'],
    shuffle=True,
    drop_last=True,
)

val_dataloader = torch.utils.data.DataLoader(
    dataset=val_dataset,
    batch_size=hparams['batch_size'],
    shuffle=False,
    drop_last=True,
)

test_dataloader = torch.utils.data.DataLoader(
    dataset=test_dataset,
    batch_size=hparams['batch_size'],
    shuffle=False,
    drop_last=True,
)
# Out:
# 12544

# %% [markdown]
# **VAE Definition**

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            channels: int,
            latent_dims: int,
            ) -> None:

        super(Encoder, self).__init__()

        self.c = channels
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=self.c, kernel_size=(25,6), stride=1, padding=3)
        self.dropout1 = nn.Dropout2d(p=hparams['dropout_prob'])
        self.conv2 = nn.Conv2d(in_channels=self.c, out_channels=self.c*2, kernel_size=7, stride=2, padding=3)
        self.dropout2 = nn.Dropout2d(p=hparams['dropout_prob'])
        self.fc_mu = nn.Linear(in_features=self.c*2*4*19, out_features=hparams['latent_dims'])
        self.fc_logvar = nn.Linear(in_features=self.c*2*4*19, out_features=hparams['latent_dims'])

    def forward(self, x: torch.Tensor)-> Tuple[torch.Tensor, torch.Tensor]:
        #print(x.shape) # [128, 1, 25, 36]
        out = F.relu(self.conv1(x))
        #print(out.shape) # [128, 64, 7, 37]
        out = self.dropout1(out)
        out = F.relu(self.conv2(out))
        #print(out.shape) # [128, 128, 4, 19]
        out = self.dropout2(out)
        out = out.view(out.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        #print(out.shape) # [128, 9728]

        x_mu = self.fc_mu(out)
        #print(x_mu.shape) # [128, 77]
        x_logvar = self.fc_logvar(out)
        #print(x_logvar.shape) # [128, 77]

        return x_mu, x_logvar

# %%
class Decoder(nn.Module):
    def __init__(
            self,
            channels: int,
            latent_dims: int
            ) -> None:

        super(Decoder, self).__init__()
        self.c = channels
        self.fc = nn.Linear(in_features=hparams['latent_dims'], out_features=self.c*2*4*19)
        self.conv2 = nn.ConvTranspose2d(in_channels=self.c*2, out_channels=self.c, kernel_size=7, stride=2, padding=3)
        self.dropout1 = nn.Dropout2d(p=hparams['dropout_prob'])
        self.conv1 = nn.ConvTranspose2d(in_channels=self.c, out_channels=1, kernel_size=(25,6), stride=1, padding=3)

    def forward(self, z: torch.Tensor) -> torch.Tensor:
        #print(z.shape) # [128, 77]

        out = self.fc(z)
        #print(out.shape) # [128, 9728]
        out = out.view(out.size(0), self.c*2, 4, 19) # unflatten batch
        #print(out.shape) # [128, 128, 4, 19]
        out = F.relu(self.conv2(out))
        #print(out.shape) # [128, 64, 7, 37]
        out = self.dropout1(out)
        out = torch.sigmoid(self.conv1(out))
        #print(out.shape) # [128, 1, 25, 36]

        return out

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(
            self,
            z_dims: int,
            n_ch: int,
            ) -> None:

        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder(channels=n_ch,latent_dims=z_dims)
        self.decoder = Decoder(channels=n_ch, latent_dims=z_dims)

    def reparametrize(
            self,
            mu:torch.Tensor,
            logvar:torch.Tensor,
            ) -> torch.Tensor:
        # Given mean and logvar returns z
        # reparameterization trick: instead of sampling from Q(z|X), sample epsilon = N(0,I)
        # mu, logvar: mean and log of variance of Q(z|X)

        # The factor 1/2 in the exponent ensures that the distribution has unit variance
        std = torch.exp(0.5 * logvar)
        # Random sample
        eps = torch.randn_like(std)
        return mu + std * eps

    def forward(self, x: torch.Tensor) -> Tuple[
            torch.Tensor, torch.Tensor, torch.Tensor]:
        latent_mu, latent_logvar = self.encoder(x)
        z = self.reparametrize(latent_mu, latent_logvar)
        x_recon = self.decoder(z)

        return x_recon, latent_mu, latent_logvar

# %% [markdown]
# **Define Loss Function**

# %%
def vae_loss(
        recon_x: torch.Tensor,
        x: torch.Tensor,
        mu: torch.Tensor,
        logvar: torch.Tensor,
        variational_beta: int=1,
        ) -> float:
    # recon_x is the probability of a multivariate Bernoulli distribution p.
    # -log(p(x)) is then the pixel-wise binary cross-entropy.

    input_size = x.size(2) * x.size(3)

    recon_loss = F.binary_cross_entropy(recon_x.view(-1, input_size), x.view(-1, input_size), reduction='sum')
    kldivergence = variational_beta * (-0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()))
    elbo_loss = (recon_loss +  kldivergence)/x.shape[0]

    return elbo_loss, recon_loss, kldivergence

# %% [markdown]
# **Training**

# %%
def train_batch(
        image_batch: torch.Tensor,
        vae: torch.nn.Module,
        vae_loss: torch.nn.Module,
        optimizer: torch.optim,
        ) -> float:

    image_batch = image_batch.to(device) # [128, 1, 25, 36]

    image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
    elbo_loss, recon_loss, kldivergence = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

    # backpropagation
    optimizer.zero_grad()
    elbo_loss.backward()

    # one step of the optmizer (using the gradients from backpropagation)
    optimizer.step()

    return elbo_loss.item(), recon_loss.item(), kldivergence.item()

# %%
start_time=time.time()

vae = VariationalAutoencoder(hparams['latent_dims'], hparams['channels']).to(device)
optimizer = torch.optim.Adam(params=vae.parameters(), lr=hparams['learning_rate'], weight_decay=hparams['weight_decay'])

# This is the number of parameters used in the model
num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print(f'Number of parameters: {num_params}')

# set to training mode
vae.train()

train_loss_avg = {"elbo": [], "likelihood": [], "kl_div": []}
val_loss_avg = {"elbo": [], "likelihood": [], "kl_div": []}

print('Training ...')
for epoch in range(hparams['num_epochs']):
    train_loss_avg["elbo"].append(0)
    train_loss_avg["likelihood"].append(0)
    train_loss_avg["kl_div"].append(0)
    num_batches = 0

    for i,(image_batch,_) in enumerate(train_dataloader):

        elbo_loss, likelihood, kl_div = train_batch(image_batch, vae, vae_loss, optimizer)
        train_loss_avg["elbo"][-1] += elbo_loss
        train_loss_avg["likelihood"][-1] += likelihood
        train_loss_avg["kl_div"][-1] += kl_div

    train_loss_avg["elbo"][-1] /= i
    train_loss_avg["likelihood"][-1] /= i
    train_loss_avg["kl_div"][-1] /= i

    print(
        f"Epoch [{epoch + 1} / {hparams['num_epochs']}] Training ELBO loss: {train_loss_avg['elbo'][-1]:.4f}, "
        f"Likelihood loss: {train_loss_avg['likelihood'][-1]:.4f}, "
        f"KL divergence loss: {train_loss_avg['kl_div'][-1]:.4f}"
    )

    # Set to validation mode
    vae.eval()
    with torch.no_grad():
        val_loss_avg["elbo"].append(0)
        val_loss_avg["likelihood"].append(0)
        val_loss_avg["kl_div"].append(0)

        for i, (x_val_batch, _) in enumerate(val_dataloader):
            x_val_batch = x_val_batch.to(device)
            x_val_batch_recon, latent_mu, latent_logvar = vae(x_val_batch)
            val_elbo_loss, val_likelihood, val_kl_div = vae_loss(x_val_batch_recon, x_val_batch, latent_mu, latent_logvar)
            val_loss_avg["elbo"][-1] += val_elbo_loss.item()
            val_loss_avg["likelihood"][-1] += val_likelihood.item()
            val_loss_avg["kl_div"][-1] += val_kl_div.item()

        val_loss_avg["elbo"][-1] /= i
        val_loss_avg["likelihood"][-1] /= i
        val_loss_avg["kl_div"][-1] /= i

        print(
            f"Epoch [{epoch + 1} / {hparams['num_epochs']}] Validation ELBO loss: {val_loss_avg['elbo'][-1]:.4f}, "
            f"Likelihood loss: {val_loss_avg['likelihood'][-1]:.4f}, "
            f"KL divergence loss: {val_loss_avg['kl_div'][-1]:.4f}"
        )
    vae.train()

print("--- TOTAL TIME: %s min ---" % (round((time.time() - start_time) / 60, 3)))
# Out:
# Number of parameters: 1999441
# Training ...
# Epoch [1 / 100] Training ELBO loss: 169.2522, Likelihood loss: 21090.1216, KL divergence loss: 574.1568
# Epoch [1 / 100] Validation ELBO loss: 138.5276, Likelihood loss: 17561.6979, KL divergence loss: 169.8330
# Epoch [2 / 100] Training ELBO loss: 128.7460, Likelihood loss: 16077.5963, KL divergence loss: 401.8920
# Epoch [2 / 100] Validation ELBO loss: 120.7582, Likelihood loss: 14801.0065, KL divergence loss: 656.0489
# Epoch [3 / 100] Training ELBO loss: 114.4154, Likelihood loss: 13581.3273, KL divergence loss: 1063.8490
# Epoch [3 / 100] Validation ELBO loss: 106.9715, Likelihood loss: 12376.8704, KL divergence loss: 1315.4799
# Epoch [4 / 100] Training ELBO loss: 101.5689, Likelihood loss: 11300.2559, KL divergence loss: 1700.5622
# Epoch [4 / 100] Validation ELBO loss: 93.2836, Likelihood loss: 9796.7214, KL divergence loss: 2143.5826
# Epoch [5 / 100] Training ELBO loss: 88.3021, Likelihood loss: 8842.5998, KL divergence loss: 2460.0729
# Epoch [5 / 100] Validation ELBO loss: 79.1184, Likelihood loss: 7509.7174, KL divergence loss: 2617.4386
# Epoch [6 / 100] Training ELBO loss: 76.2938, Likelihood loss: 6592.4412, KL divergence loss: 3173.1649
# Epoch [6 / 100] Validation ELBO loss: 68.5782, Likelihood loss: 5231.3066, KL divergence loss: 3546.7061
# Epoch [7 / 100] Training ELBO loss: 67.8571, Likelihood loss: 5009.4327, KL divergence loss: 3676.2802
# Epoch [7 / 100] Validation ELBO loss: 61.4658, Likelihood loss: 4088.0914, KL divergence loss: 3779.5257
# Epoch [8 / 100] Training ELBO loss: 62.8254, Likelihood loss: 4061.3287, KL divergence loss: 3980.3216
# Epoch [8 / 100] Validation ELBO loss: 58.1351, Likelihood loss: 3582.7941, KL divergence loss: 3858.4958
# Epoch [9 / 100] Training ELBO loss: 59.3563, Likelihood loss: 3497.4234, KL divergence loss: 4100.1803
# Epoch [9 / 100] Validation ELBO loss: 56.2637, Likelihood loss: 3076.0496, KL divergence loss: 4125.7053
# Epoch [10 / 100] Training ELBO loss: 56.9999, Likelihood loss: 3119.0536, KL divergence loss: 4176.9384
# Epoch [10 / 100] Validation ELBO loss: 54.1198, Likelihood loss: 2632.4391, KL divergence loss: 4294.8904
# Epoch [11 / 100] Training ELBO loss: 55.4742, Likelihood loss: 2861.3302, KL divergence loss: 4239.3720
# Epoch [11 / 100] Validation ELBO loss: 52.5982, Likelihood loss: 2485.7110, KL divergence loss: 4246.8625
# Epoch [12 / 100] Training ELBO loss: 54.5566, Likelihood loss: 2726.8567, KL divergence loss: 4256.3932
# Epoch [12 / 100] Validation ELBO loss: 51.9626, Likelihood loss: 2261.8990, KL divergence loss: 4389.3109
# Epoch [13 / 100] Training ELBO loss: 53.3992, Likelihood loss: 2578.3526, KL divergence loss: 4256.7422
# Epoch [13 / 100] Validation ELBO loss: 51.7388, Likelihood loss: 2057.2674, KL divergence loss: 4565.2931
# Epoch [14 / 100] Training ELBO loss: 52.5799, Likelihood loss: 2461.3146, KL divergence loss: 4268.9144
# Epoch [14 / 100] Validation ELBO loss: 51.0630, Likelihood loss: 2089.8825, KL divergence loss: 4446.1815
# Epoch [15 / 100] Training ELBO loss: 51.5809, Likelihood loss: 2329.9186, KL divergence loss: 4272.4305
# Epoch [15 / 100] Validation ELBO loss: 50.7123, Likelihood loss: 2571.7594, KL divergence loss: 3919.4120
# Epoch [16 / 100] Training ELBO loss: 51.3965, Likelihood loss: 2286.8304, KL divergence loss: 4291.9277
# Epoch [16 / 100] Validation ELBO loss: 49.8069, Likelihood loss: 2023.9846, KL divergence loss: 4351.2980
# Epoch [17 / 100] Training ELBO loss: 50.8794, Likelihood loss: 2226.2342, KL divergence loss: 4286.3342
# Epoch [17 / 100] Validation ELBO loss: 49.7417, Likelihood loss: 1871.0419, KL divergence loss: 4495.8915
# Epoch [18 / 100] Training ELBO loss: 50.0188, Likelihood loss: 2133.2443, KL divergence loss: 4269.1627
# Epoch [18 / 100] Validation ELBO loss: 49.3953, Likelihood loss: 1969.5344, KL divergence loss: 4353.0703
# Epoch [19 / 100] Training ELBO loss: 49.7722, Likelihood loss: 2095.2688, KL divergence loss: 4275.5697
# Epoch [19 / 100] Validation ELBO loss: 48.9951, Likelihood loss: 1899.0151, KL divergence loss: 4372.3541
# Epoch [20 / 100] Training ELBO loss: 49.1652, Likelihood loss: 2041.7116, KL divergence loss: 4251.4371
# Epoch [20 / 100] Validation ELBO loss: 48.5707, Likelihood loss: 1780.6294, KL divergence loss: 4436.4169
# Epoch [21 / 100] Training ELBO loss: 48.9893, Likelihood loss: 2005.6581, KL divergence loss: 4264.9675
# Epoch [21 / 100] Validation ELBO loss: 48.2060, Likelihood loss: 1693.4520, KL divergence loss: 4476.9223
# Epoch [22 / 100] Training ELBO loss: 48.6319, Likelihood loss: 1958.3273, KL divergence loss: 4266.5617
# Epoch [22 / 100] Validation ELBO loss: 48.6905, Likelihood loss: 2052.2197, KL divergence loss: 4180.1669
# Epoch [23 / 100] Training ELBO loss: 48.2833, Likelihood loss: 1925.5576, KL divergence loss: 4254.7056
# Epoch [23 / 100] Validation ELBO loss: 47.6874, Likelihood loss: 1819.8375, KL divergence loss: 4284.1456
# Epoch [24 / 100] Training ELBO loss: 48.0085, Likelihood loss: 1878.6887, KL divergence loss: 4266.3987
# Epoch [24 / 100] Validation ELBO loss: 47.7327, Likelihood loss: 1820.1468, KL divergence loss: 4289.6447
# Epoch [25 / 100] Training ELBO loss: 47.6906, Likelihood loss: 1852.3577, KL divergence loss: 4252.0397
# Epoch [25 / 100] Validation ELBO loss: 47.7433, Likelihood loss: 1944.8593, KL divergence loss: 4166.2881
# Epoch [26 / 100] Training ELBO loss: 47.6408, Likelihood loss: 1838.0631, KL divergence loss: 4259.9624
# Epoch [26 / 100] Validation ELBO loss: 47.5351, Likelihood loss: 1917.9132, KL divergence loss: 4166.5770
# Epoch [27 / 100] Training ELBO loss: 47.1661, Likelihood loss: 1809.3814, KL divergence loss: 4227.8732
# Epoch [27 / 100] Validation ELBO loss: 47.1863, Likelihood loss: 1547.1715, KL divergence loss: 4492.6793
# Epoch [28 / 100] Training ELBO loss: 47.2450, Likelihood loss: 1784.2413, KL divergence loss: 4263.1190
# Epoch [28 / 100] Validation ELBO loss: 47.3760, Likelihood loss: 1500.3764, KL divergence loss: 4563.7574
# Epoch [29 / 100] Training ELBO loss: 46.8461, Likelihood loss: 1742.1444, KL divergence loss: 4254.1619
# Epoch [29 / 100] Validation ELBO loss: 46.9364, Likelihood loss: 1601.6210, KL divergence loss: 4406.2417
# Epoch [30 / 100] Training ELBO loss: 46.6897, Likelihood loss: 1719.6025, KL divergence loss: 4256.6807
# Epoch [30 / 100] Validation ELBO loss: 46.3550, Likelihood loss: 1668.5055, KL divergence loss: 4264.9365
# Epoch [31 / 100] Training ELBO loss: 46.5281, Likelihood loss: 1711.2283, KL divergence loss: 4244.3654
# Epoch [31 / 100] Validation ELBO loss: 46.8775, Likelihood loss: 1563.4465, KL divergence loss: 4436.8786
# Epoch [32 / 100] Training ELBO loss: 46.3482, Likelihood loss: 1695.9145, KL divergence loss: 4236.6544
# Epoch [32 / 100] Validation ELBO loss: 46.4642, Likelihood loss: 1846.3357, KL divergence loss: 4101.0838
# Epoch [33 / 100] Training ELBO loss: 46.0844, Likelihood loss: 1668.9509, KL divergence loss: 4229.8547
# Epoch [33 / 100] Validation ELBO loss: 46.6939, Likelihood loss: 1604.2053, KL divergence loss: 4372.6188
# Epoch [34 / 100] Training ELBO loss: 45.8958, Likelihood loss: 1641.6893, KL divergence loss: 4232.9742
# Epoch [34 / 100] Validation ELBO loss: 46.5522, Likelihood loss: 1684.2421, KL divergence loss: 4274.4338
# Epoch [35 / 100] Training ELBO loss: 46.0281, Likelihood loss: 1653.0219, KL divergence loss: 4238.5791
# Epoch [35 / 100] Validation ELBO loss: 46.0300, Likelihood loss: 1714.6008, KL divergence loss: 4177.2437
# Epoch [36 / 100] Training ELBO loss: 45.5646, Likelihood loss: 1621.2281, KL divergence loss: 4211.0367
# Epoch [36 / 100] Validation ELBO loss: 45.9830, Likelihood loss: 1768.1940, KL divergence loss: 4117.6330
# Epoch [37 / 100] Training ELBO loss: 45.5951, Likelihood loss: 1602.4619, KL divergence loss: 4233.7116
# Epoch [37 / 100] Validation ELBO loss: 45.7507, Likelihood loss: 1434.9736, KL divergence loss: 4421.1160
# Epoch [38 / 100] Training ELBO loss: 45.3826, Likelihood loss: 1594.7865, KL divergence loss: 4214.1880
# Epoch [38 / 100] Validation ELBO loss: 46.0966, Likelihood loss: 1519.9850, KL divergence loss: 4380.3768
# Epoch [39 / 100] Training ELBO loss: 45.1745, Likelihood loss: 1562.1172, KL divergence loss: 4220.2206
# Epoch [39 / 100] Validation ELBO loss: 45.8341, Likelihood loss: 1762.7203, KL divergence loss: 4104.0471
# Epoch [40 / 100] Training ELBO loss: 45.1689, Likelihood loss: 1578.0456, KL divergence loss: 4203.5737
# Epoch [40 / 100] Validation ELBO loss: 45.8130, Likelihood loss: 1590.3165, KL divergence loss: 4273.7469
# Epoch [41 / 100] Training ELBO loss: 45.0839, Likelihood loss: 1562.1422, KL divergence loss: 4208.5921
# Epoch [41 / 100] Validation ELBO loss: 45.4517, Likelihood loss: 1498.9822, KL divergence loss: 4318.8329
# Epoch [42 / 100] Training ELBO loss: 44.8238, Likelihood loss: 1546.2613, KL divergence loss: 4191.1899
# Epoch [42 / 100] Validation ELBO loss: 45.6786, Likelihood loss: 1599.4314, KL divergence loss: 4247.4261
# Epoch [43 / 100] Training ELBO loss: 44.9593, Likelihood loss: 1551.4088, KL divergence loss: 4203.3845
# Epoch [43 / 100] Validation ELBO loss: 45.4881, Likelihood loss: 1649.0468, KL divergence loss: 4173.4338
# Epoch [44 / 100] Training ELBO loss: 44.6495, Likelihood loss: 1512.6144, KL divergence loss: 4202.5222
# Epoch [44 / 100] Validation ELBO loss: 45.5890, Likelihood loss: 1523.3739, KL divergence loss: 4312.0170
# Epoch [45 / 100] Training ELBO loss: 44.6900, Likelihood loss: 1520.6341, KL divergence loss: 4199.6825
# Epoch [45 / 100] Validation ELBO loss: 45.5530, Likelihood loss: 1340.1669, KL divergence loss: 4490.6175
# Epoch [46 / 100] Training ELBO loss: 44.5908, Likelihood loss: 1500.8323, KL divergence loss: 4206.7917
# Epoch [46 / 100] Validation ELBO loss: 45.3992, Likelihood loss: 1636.3101, KL divergence loss: 4174.7835
# Epoch [47 / 100] Training ELBO loss: 44.3581, Likelihood loss: 1490.4460, KL divergence loss: 4187.3851
# Epoch [47 / 100] Validation ELBO loss: 45.4285, Likelihood loss: 1596.4262, KL divergence loss: 4218.4190
# Epoch [48 / 100] Training ELBO loss: 44.3564, Likelihood loss: 1500.9685, KL divergence loss: 4176.6557
# Epoch [48 / 100] Validation ELBO loss: 45.4898, Likelihood loss: 1383.4745, KL divergence loss: 4439.2185
# Epoch [49 / 100] Training ELBO loss: 44.2199, Likelihood loss: 1472.3703, KL divergence loss: 4187.7791
# Epoch [49 / 100] Validation ELBO loss: 45.3097, Likelihood loss: 1686.8361, KL divergence loss: 4112.8115
# Epoch [50 / 100] Training ELBO loss: 44.1512, Likelihood loss: 1472.9160, KL divergence loss: 4178.4340
# Epoch [50 / 100] Validation ELBO loss: 44.8710, Likelihood loss: 1536.2044, KL divergence loss: 4207.2832
# Epoch [51 / 100] Training ELBO loss: 44.0878, Likelihood loss: 1455.6105, KL divergence loss: 4187.6221
# Epoch [51 / 100] Validation ELBO loss: 44.7289, Likelihood loss: 1600.4532, KL divergence loss: 4124.8417
# Epoch [52 / 100] Training ELBO loss: 43.7675, Likelihood loss: 1443.3723, KL divergence loss: 4158.8614
# Epoch [52 / 100] Validation ELBO loss: 44.5931, Likelihood loss: 1629.9343, KL divergence loss: 4077.9812
# Epoch [53 / 100] Training ELBO loss: 43.8081, Likelihood loss: 1452.6622, KL divergence loss: 4154.7791
# Epoch [53 / 100] Validation ELBO loss: 45.0688, Likelihood loss: 1637.6535, KL divergence loss: 4131.1488
# Epoch [54 / 100] Training ELBO loss: 43.8473, Likelihood loss: 1439.4008, KL divergence loss: 4173.0598
# Epoch [54 / 100] Validation ELBO loss: 45.4543, Likelihood loss: 1655.3744, KL divergence loss: 4162.7824
# Epoch [55 / 100] Training ELBO loss: 43.8373, Likelihood loss: 1438.0690, KL divergence loss: 4173.0991
# Epoch [55 / 100] Validation ELBO loss: 44.6887, Likelihood loss: 1580.7284, KL divergence loss: 4139.4231
# Epoch [56 / 100] Training ELBO loss: 43.7072, Likelihood loss: 1425.3090, KL divergence loss: 4169.2104
# Epoch [56 / 100] Validation ELBO loss: 44.8140, Likelihood loss: 1467.3640, KL divergence loss: 4268.8335
# Epoch [57 / 100] Training ELBO loss: 43.4915, Likelihood loss: 1408.2526, KL divergence loss: 4158.6531
# Epoch [57 / 100] Validation ELBO loss: 44.6372, Likelihood loss: 1496.9387, KL divergence loss: 4216.6237
# Epoch [58 / 100] Training ELBO loss: 43.6128, Likelihood loss: 1420.0410, KL divergence loss: 4162.3919
# Epoch [58 / 100] Validation ELBO loss: 44.5989, Likelihood loss: 1399.6699, KL divergence loss: 4308.9899
# Epoch [59 / 100] Training ELBO loss: 43.6221, Likelihood loss: 1426.4616, KL divergence loss: 4157.1723
# Epoch [59 / 100] Validation ELBO loss: 44.7617, Likelihood loss: 1395.7121, KL divergence loss: 4333.7831
# Epoch [60 / 100] Training ELBO loss: 43.3646, Likelihood loss: 1395.4843, KL divergence loss: 4155.1798
# Epoch [60 / 100] Validation ELBO loss: 44.5976, Likelihood loss: 1511.2286, KL divergence loss: 4197.2706
# Epoch [61 / 100] Training ELBO loss: 43.1993, Likelihood loss: 1388.3564, KL divergence loss: 4141.1575
# Epoch [61 / 100] Validation ELBO loss: 44.7881, Likelihood loss: 1508.2102, KL divergence loss: 4224.6707
# Epoch [62 / 100] Training ELBO loss: 43.4234, Likelihood loss: 1386.0296, KL divergence loss: 4172.1670
# Epoch [62 / 100] Validation ELBO loss: 44.7398, Likelihood loss: 1748.8735, KL divergence loss: 3977.8252
# Epoch [63 / 100] Training ELBO loss: 43.2619, Likelihood loss: 1383.4118, KL divergence loss: 4154.1174
# Epoch [63 / 100] Validation ELBO loss: 44.1918, Likelihood loss: 1568.6856, KL divergence loss: 4087.8648
# Epoch [64 / 100] Training ELBO loss: 43.0829, Likelihood loss: 1378.1663, KL divergence loss: 4136.4486
# Epoch [64 / 100] Validation ELBO loss: 44.3688, Likelihood loss: 1455.0215, KL divergence loss: 4224.1802
# Epoch [65 / 100] Training ELBO loss: 43.1493, Likelihood loss: 1381.0616, KL divergence loss: 4142.0534
# Epoch [65 / 100] Validation ELBO loss: 44.4939, Likelihood loss: 1497.1911, KL divergence loss: 4198.0307
# Epoch [66 / 100] Training ELBO loss: 43.0057, Likelihood loss: 1367.0693, KL divergence loss: 4137.6586
# Epoch [66 / 100] Validation ELBO loss: 44.1253, Likelihood loss: 1413.1129, KL divergence loss: 4234.9306
# Epoch [67 / 100] Training ELBO loss: 42.9863, Likelihood loss: 1370.0793, KL divergence loss: 4132.1616
# Epoch [67 / 100] Validation ELBO loss: 44.4618, Likelihood loss: 1426.0048, KL divergence loss: 4265.1080
# Epoch [68 / 100] Training ELBO loss: 42.8316, Likelihood loss: 1343.7483, KL divergence loss: 4138.7028
# Epoch [68 / 100] Validation ELBO loss: 44.4973, Likelihood loss: 1490.9560, KL divergence loss: 4204.7009
# Epoch [69 / 100] Training ELBO loss: 42.5960, Likelihood loss: 1331.7086, KL divergence loss: 4120.5768
# Epoch [69 / 100] Validation ELBO loss: 44.0721, Likelihood loss: 1481.5476, KL divergence loss: 4159.6749
# Epoch [70 / 100] Training ELBO loss: 42.6873, Likelihood loss: 1349.6695, KL divergence loss: 4114.3009
# Epoch [70 / 100] Validation ELBO loss: 44.7126, Likelihood loss: 1293.1052, KL divergence loss: 4430.1098
# Epoch [71 / 100] Training ELBO loss: 42.5864, Likelihood loss: 1326.7874, KL divergence loss: 4124.2741
# Epoch [71 / 100] Validation ELBO loss: 44.2361, Likelihood loss: 1577.8588, KL divergence loss: 4084.3665
# Epoch [72 / 100] Training ELBO loss: 42.4610, Likelihood loss: 1323.2191, KL divergence loss: 4111.7832
# Epoch [72 / 100] Validation ELBO loss: 44.0868, Likelihood loss: 1644.4126, KL divergence loss: 3998.6965
# Epoch [73 / 100] Training ELBO loss: 42.6013, Likelihood loss: 1322.2467, KL divergence loss: 4130.7235
# Epoch [73 / 100] Validation ELBO loss: 43.9583, Likelihood loss: 1495.4835, KL divergence loss: 4131.1798
# Epoch [74 / 100] Training ELBO loss: 42.4573, Likelihood loss: 1321.8138, KL divergence loss: 4112.7247
# Epoch [74 / 100] Validation ELBO loss: 44.1219, Likelihood loss: 1442.6973, KL divergence loss: 4204.9064
# Epoch [75 / 100] Training ELBO loss: 42.5091, Likelihood loss: 1320.3319, KL divergence loss: 4120.8269
# Epoch [75 / 100] Validation ELBO loss: 44.3663, Likelihood loss: 1728.8008, KL divergence loss: 3950.0799
# Epoch [76 / 100] Training ELBO loss: 42.1784, Likelihood loss: 1303.3945, KL divergence loss: 4095.4395
# Epoch [76 / 100] Validation ELBO loss: 43.5227, Likelihood loss: 1509.7447, KL divergence loss: 4061.1630
# Epoch [77 / 100] Training ELBO loss: 42.4499, Likelihood loss: 1325.6000, KL divergence loss: 4107.9907
# Epoch [77 / 100] Validation ELBO loss: 43.8631, Likelihood loss: 1592.6329, KL divergence loss: 4021.8455
# Epoch [78 / 100] Training ELBO loss: 42.1695, Likelihood loss: 1302.5388, KL divergence loss: 4095.1601
# Epoch [78 / 100] Validation ELBO loss: 44.4016, Likelihood loss: 1709.0071, KL divergence loss: 3974.4028
# Epoch [79 / 100] Training ELBO loss: 42.1790, Likelihood loss: 1300.6924, KL divergence loss: 4098.2152
# Epoch [79 / 100] Validation ELBO loss: 44.2318, Likelihood loss: 1600.8178, KL divergence loss: 4060.8543
# Epoch [80 / 100] Training ELBO loss: 42.0768, Likelihood loss: 1296.9140, KL divergence loss: 4088.9224
# Epoch [80 / 100] Validation ELBO loss: 43.8260, Likelihood loss: 1476.2832, KL divergence loss: 4133.4389
# Epoch [81 / 100] Training ELBO loss: 42.1410, Likelihood loss: 1311.5414, KL divergence loss: 4082.5017
# Epoch [81 / 100] Validation ELBO loss: 43.8134, Likelihood loss: 1384.4572, KL divergence loss: 4223.6538
# Epoch [82 / 100] Training ELBO loss: 41.9867, Likelihood loss: 1279.9527, KL divergence loss: 4094.3484
# Epoch [82 / 100] Validation ELBO loss: 43.7472, Likelihood loss: 1516.5777, KL divergence loss: 4083.0594
# Epoch [83 / 100] Training ELBO loss: 41.8561, Likelihood loss: 1281.9937, KL divergence loss: 4075.5920
# Epoch [83 / 100] Validation ELBO loss: 43.8766, Likelihood loss: 1599.4363, KL divergence loss: 4016.7682
# Epoch [84 / 100] Training ELBO loss: 41.8660, Likelihood loss: 1278.4920, KL divergence loss: 4080.3606
# Epoch [84 / 100] Validation ELBO loss: 43.5901, Likelihood loss: 1443.2196, KL divergence loss: 4136.3115
# Epoch [85 / 100] Training ELBO loss: 41.8964, Likelihood loss: 1278.3541, KL divergence loss: 4084.3845
# Epoch [85 / 100] Validation ELBO loss: 43.9567, Likelihood loss: 1477.7465, KL divergence loss: 4148.7174
# Epoch [86 / 100] Training ELBO loss: 42.0293, Likelihood loss: 1281.2477, KL divergence loss: 4098.5037
# Epoch [86 / 100] Validation ELBO loss: 43.8795, Likelihood loss: 1348.6301, KL divergence loss: 4267.9401
# Epoch [87 / 100] Training ELBO loss: 41.8773, Likelihood loss: 1262.0063, KL divergence loss: 4098.2834
# Epoch [87 / 100] Validation ELBO loss: 43.7482, Likelihood loss: 1425.2376, KL divergence loss: 4174.5319
# Epoch [88 / 100] Training ELBO loss: 41.7844, Likelihood loss: 1270.0326, KL divergence loss: 4078.3726
# Epoch [88 / 100] Validation ELBO loss: 43.7781, Likelihood loss: 1559.0662, KL divergence loss: 4044.5304
# Epoch [89 / 100] Training ELBO loss: 41.8423, Likelihood loss: 1281.6617, KL divergence loss: 4074.1478
# Epoch [89 / 100] Validation ELBO loss: 43.9406, Likelihood loss: 1365.5191, KL divergence loss: 4258.8786
# Epoch [90 / 100] Training ELBO loss: 41.6998, Likelihood loss: 1255.6012, KL divergence loss: 4081.9703
# Epoch [90 / 100] Validation ELBO loss: 43.9188, Likelihood loss: 1402.1735, KL divergence loss: 4219.4393
# Epoch [91 / 100] Training ELBO loss: 41.6433, Likelihood loss: 1263.3419, KL divergence loss: 4066.9972
# Epoch [91 / 100] Validation ELBO loss: 43.7581, Likelihood loss: 1576.7498, KL divergence loss: 4024.2832
# Epoch [92 / 100] Training ELBO loss: 41.6215, Likelihood loss: 1265.4234, KL divergence loss: 4062.1306
# Epoch [92 / 100] Validation ELBO loss: 43.4489, Likelihood loss: 1397.9568, KL divergence loss: 4163.4961
# Epoch [93 / 100] Training ELBO loss: 41.6966, Likelihood loss: 1257.3216, KL divergence loss: 4079.8378
# Epoch [93 / 100] Validation ELBO loss: 43.4543, Likelihood loss: 1408.9292, KL divergence loss: 4153.2191
# Epoch [94 / 100] Training ELBO loss: 41.4307, Likelihood loss: 1235.3197, KL divergence loss: 4067.8141
# Epoch [94 / 100] Validation ELBO loss: 43.4957, Likelihood loss: 1400.2099, KL divergence loss: 4167.2384
# Epoch [95 / 100] Training ELBO loss: 41.2924, Likelihood loss: 1236.2072, KL divergence loss: 4049.2157
# Epoch [95 / 100] Validation ELBO loss: 43.5515, Likelihood loss: 1497.6332, KL divergence loss: 4076.9526
# Epoch [96 / 100] Training ELBO loss: 41.2867, Likelihood loss: 1237.5141, KL divergence loss: 4047.1802
# Epoch [96 / 100] Validation ELBO loss: 43.7274, Likelihood loss: 1332.7702, KL divergence loss: 4264.3406
# Epoch [97 / 100] Training ELBO loss: 41.5169, Likelihood loss: 1242.7681, KL divergence loss: 4071.3933
# Epoch [97 / 100] Validation ELBO loss: 43.8939, Likelihood loss: 1624.6891, KL divergence loss: 3993.7313
# Epoch [98 / 100] Training ELBO loss: 41.4260, Likelihood loss: 1238.6983, KL divergence loss: 4063.8358
# Epoch [98 / 100] Validation ELBO loss: 43.3248, Likelihood loss: 1462.2914, KL divergence loss: 4083.2774
# Epoch [99 / 100] Training ELBO loss: 41.4819, Likelihood loss: 1249.3318, KL divergence loss: 4060.3497
# Epoch [99 / 100] Validation ELBO loss: 43.6637, Likelihood loss: 1487.3388, KL divergence loss: 4101.6148
# Epoch [100 / 100] Training ELBO loss: 41.3379, Likelihood loss: 1235.6851, KL divergence loss: 4055.5675
# Epoch [100 / 100] Validation ELBO loss: 43.7393, Likelihood loss: 1426.0621, KL divergence loss: 4172.5709
# --- TOTAL TIME: 40.137 min ---

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
# fig.tight_layout()

loss_types = ["elbo", "likelihood", "kl_div"]
y_labels = ["ELBO Loss", "Likelihood Loss", "KL Divergence Loss"]

for i, loss_type in enumerate(loss_types):
    (train_h,) = axs[i].plot(train_loss_avg[loss_type], label="Train")
    (val_h,) = axs[i].plot(val_loss_avg[loss_type], label="Validation")
    axs[i].set_xlabel("Epochs")
    axs[i].set_title(y_labels[i])
    axs[i].grid(True)

fig.legend(handles=[train_h, val_h], loc="upper center", bbox_to_anchor=(0.5, 1.15))
plt.show()

# %%
plt.figure(figsize=(8, 6))

train_elbo, = plt.plot(train_loss_avg['elbo'], label="Train ELBO Loss")
val_elbo, = plt.plot(val_loss_avg['elbo'], label="Validation ELBO Loss")

plt.xlabel("Epochs")
plt.ylabel("ELBO Loss")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate on the Test Set

# %%
# Set to evaluation mode
vae.eval()

with torch.no_grad():
    test_loss_avg = {"elbo": 0, "likelihood": 0, "kl_div": 0}
    num_test_batches = 0

    for x_test_batch, _ in test_dataloader:
        x_test_batch = x_test_batch.to(device)

        # VAE reconstruction
        x_test_batch_recon, latent_mu_test, latent_logvar_test = vae(
            x_test_batch
        )

        # Calculate reconstruction error and other losses
        test_loss, likelihood, kl_div = vae_loss(
            x_test_batch_recon,
            x_test_batch,
            latent_mu_test,
            latent_logvar_test,
        )

        test_loss_avg["elbo"] += test_loss.item()
        test_loss_avg["likelihood"] += likelihood.item()
        test_loss_avg["kl_div"] += kl_div.item()
        num_test_batches += 1

    # Calculate average losses
    test_loss_avg["elbo"] /= num_test_batches
    test_loss_avg["likelihood"] /= num_test_batches
    test_loss_avg["kl_div"] /= num_test_batches

# Print and save the test losses
print("Average ELBO loss on test data: %f" % test_loss_avg["elbo"])
print("Average Likelihood loss on test data: %f" % test_loss_avg["likelihood"])
print("Average KL Divergence loss on test data: %f" % test_loss_avg["kl_div"])
# Out:
# Average ELBO loss on test data: 41.172326
# Average Likelihood loss on test data: 1311.396661
# Average KL Divergence loss on test data: 3958.661133

# %% [markdown]
# **Visualize Generated Images**

# %%
# This function takes as an input the images to reconstruct
# and the name of the model with which the reconstructions
# are performed
def to_img(x: torch.Tensor) -> torch.Tensor:
    x = x.clamp(0, 1)
    return x

def show_image(img: torch.Tensor) -> None:
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)), cmap='gray')

def one_hot_encode(image: torch.Tensor) -> torch.Tensor:
    max_indices = torch.argmax(image, dim=1, keepdim=True)
    binary_image = torch.zeros_like(image)
    binary_image.scatter_(1, max_indices, 1)
    return image
    #return binary_image

@torch.no_grad()
def visualise_output(images: torch.Tensor, model: nn.Module, device: torch.device) -> None:
    images = images.to(device)
    model.to(device)
    recon_images, _, _ = model(images)
    recon_images = recon_images.cpu()

    # Plot each original-reconstructed pair separately
    for i in range(images.size(0)):
        plt.figure(figsize=(10, 5))

        plt.subplot(1, 2, 1)
        plt.title('Original Image')
        show_image(one_hot_encode(images[i].cpu()))

        plt.subplot(1, 2, 2)
        plt.title('Reconstructed Image')
        show_image(one_hot_encode(recon_images[i]))

        plt.show()

# %%
vae.eval()
test_data_iterator = iter(test_dataloader)
images, labels = next(test_data_iterator)

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images[1:10], vae, device)
# Out:
# VAE reconstruction:

# %% [markdown]
# **Save the trained model**

# %%
# this is how the VAE parameters can be saved:
torch.save(vae.state_dict(), '/content/drive/MyDrive/UNI/my_vae_2bar_2.pth')
#torch.save(vae.state_dict(), '/content/drive/MyDrive/TFM/my_vae_2bar_2.pth')

# %% [markdown]
# **Load the trained model**

# %%
# Load checkpoint
checkpoint=torch.load('/content/drive/MyDrive/TFM/my_vae_2bar_2.pth', map_location=torch.device('cpu'))

vae = VariationalAutoencoder(z_dims = hparams['latent_dims'], n_ch = hparams['channels'])
vae.load_state_dict(checkpoint)
print('model loaded')

# %% [markdown]
# **Analyze Latent Space**

# %%
# Get L matrix

# Initialize empty lists to store latent_mu and latent_logvar for the entire test set
latent_mu_list = []
latent_logvar_list = []

# Set the model to evaluation mode
vae.eval().to(device)

with torch.no_grad():
    for x_test_batch, _ in test_dataloader:
        x_test_batch = x_test_batch.to(device)

        # Obtain latent_mu and latent_logvar from the encoder
        latent_mu, latent_logvar = vae.encoder(x_test_batch)

        # Append latent_mu and latent_logvar to the respective lists
        latent_mu_list.append(latent_mu.cpu().numpy())
        latent_logvar_list.append(latent_logvar.cpu().numpy())

# Combine all latent_mu and latent_logvar into single matrices
latent_mu_test = np.concatenate(latent_mu_list, axis=0)
latent_logvar_test = np.concatenate(latent_logvar_list, axis=0)

# Combine mu and logvar into one matrix
latent_matrix = np.concatenate((latent_mu_test, latent_logvar_test), axis=1)
#latent_matrix = latent_mu_test

# %%
# Assuming latent_matrix is the concatenated matrix

print("Shape of Latent Matrix:", latent_matrix.shape)
# 1152 samples in test set (rows)
# 77*2 latent dimension = features (columns)

# Visualizing a heatmap of the matrix
plt.figure(figsize=(8, 6))
sns.heatmap(latent_matrix[:100], cmap='viridis')  # Displaying the first 100 rows as a heatmap
plt.title('Latent Matrix Heatmap (Sample)')
plt.xlabel('Latent Dimensions')
plt.ylabel('Sample Index')
plt.show()
# Out:
# Shape of Latent Matrix: (1152, 140)

# %%
# Perform Singular Value Decomposition (SVD)
U, s, V = np.linalg.svd(latent_matrix, full_matrices=False)

# %%
SignValue = s
plt.plot(SignValue,'.-');
plt.title(f'Plot of the value of the singular values of latent matrix')
plt.ylabel('Singular Value')
plt.xlabel('Order of the Singular Value')
plt.grid(True)
plt.show()

plt.plot(np.cumsum(SignValue)/np.sum(SignValue)*100,'.-');
plt.title(f'Cummulative plot of the value of the Singular Values of latent matrix')
plt.ylabel('Cummulative Value (%)')
plt.xlabel('Order of the Singular Value')
plt.grid(True)
plt.show()

# %%
# Perform Principal Component Analysis (PCA)
num_components = hparams['latent_dims']

#pca = PCA(n_components=40)
pca = PCA(n_components=num_components)
pca_result = pca.fit_transform(latent_matrix)
print(pca.n_components_)
# Out:
# 40

# %%
# Obtain the explained variance ratios and cumulative explained variance
explained_variance_ratios = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratios)

# Plotting the scree plot
#plt.figure(figsize=(8, 6))
plt.plot(range(1, len(explained_variance_ratios) + 1), explained_variance_ratios, '.-')
plt.title('Scree Plot for Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

# Plotting cumulative explained variance
#plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, '.-')
plt.title('Cumulative Explained Variance Ratio by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5)
plt.title('PCA Visualization of Latent Space')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# **Visualize Latent Space**

# %%
# t-SNE
tsne = TSNE(n_components=2, random_state=42)
latent_tsne = tsne.fit_transform(latent_matrix)
print(latent_tsne.shape)

# %%
# Plotting t-SNE
plt.scatter(latent_tsne[:, 0], latent_tsne[:, 1], alpha=0.5)
plt.title('t-SNE Visualization of Latent Space')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()

# %%
# MDS
mds = MDS(n_components=2, random_state=42)
latent_mds = mds.fit_transform(latent_matrix)
print(latent_mds.shape)

# %%
# Plotting MDS
plt.scatter(latent_mds[:, 0], latent_mds[:, 1], alpha=0.5)
plt.title('MDS Visualization of Latent Space')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()

# %%
# UMAP
umap_emb = umap.UMAP(n_components=2, random_state=42)
latent_umap = umap_emb.fit_transform(latent_matrix)
print(latent_umap.shape)

# %%
# Plotting UMAP
plt.scatter(latent_umap[:, 0], latent_umap[:, 1], alpha=0.5)
plt.title('UMAP Visualization of Latent Space')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()
